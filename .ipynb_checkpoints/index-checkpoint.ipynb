# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>
#
#
#
#
#
#
#
#
#
#
# # Multivariate Geostats: Beyond classical Clustering and Regression

# %% [markdown]
# ## Getting Ready

# %% [markdown]
# ### The Data
#
#
# Let's use the data from Peru previously seen:

# %%
import geopandas as gpd

peruDataLink="https://github.com/CienciaDeDatosEspacial/dataSets/raw/refs/heads/main/PERU/PeruMaps.gpkg"
DisMap=gpd.read_file(peruDataLink,layer='good_geom')

# %% [markdown]
# The "good_geom" layer is a new layer we had to use because it show no relevant topological issues (we had previously used one with some issues not detected).
#
# Rememeber this "good map" has isolates:

# %%
from libpysal.graph import Graph

DisMap_adjaceny=Graph.build_contiguity(DisMap)
DisMap_adjaceny.isolates
# Out:
# Index([51, 58], dtype='int64', name='focal')

# %% [markdown]
# Let's subset now, and avoid future warnings:

# %%
DisMap.drop(index=DisMap_adjaceny.isolates,inplace=True)
DisMap.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Preprocessing
#
# We have these columns:

# %%
DisMap.columns
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'ubigeo', 'Poblacion',
#        'IDH2019', 'Educ_sec_comp2019_pct', 'NBI2017_pct',
#        'Viv_sin_serv_hig2017_pct', 'geometry'],
#       dtype='object')

# %% [markdown]
# Let me select the columns we will use:

# %%
selected_variables = ['Educ_sec_comp2019_pct','NBI2017_pct', 'Viv_sin_serv_hig2017_pct']

# %% [markdown]
# Let's see the descriptives, paying attention to **range**:

# %%
DisMap[selected_variables].describe()
# Out:
#        Educ_sec_comp2019_pct  NBI2017_pct  Viv_sin_serv_hig2017_pct
# count            1871.000000  1871.000000               1871.000000
# mean               55.760485    38.586692                 17.074826
# std                15.738319    18.295127                 16.364994
# min                11.974433     1.100000                  0.000000
# 25%                44.451173    24.900000                  4.900000
# 50%                57.043976    35.300000                 12.100000
# 75%                68.220200    49.250000                 24.100000
# max                91.744878    99.400000                 96.500000

# %% [markdown]
# Let me check their monotony:

# %%
DisMap[selected_variables].corr()
# Out:
#                           Educ_sec_comp2019_pct  NBI2017_pct  \
# Educ_sec_comp2019_pct                  1.000000    -0.429768
# NBI2017_pct                           -0.429768     1.000000
# Viv_sin_serv_hig2017_pct              -0.201020     0.662596
#
#                           Viv_sin_serv_hig2017_pct
# Educ_sec_comp2019_pct                    -0.201020
# NBI2017_pct                               0.662596
# Viv_sin_serv_hig2017_pct                  1.000000

# %% [markdown]
# Clearly, 'Educ_sec_comp2019_pct' represents a diffent monotonic direction than the rest, because it measures a positive concept, while the others measure negative ones.
#
# Here, we can reverse the values of *Educ_sec_comp2019_pct*:

# %%
## from complete to 'incomplete'
DisMap['Educ_sec_incomp2019_pct']=100-DisMap['Educ_sec_comp2019_pct']

# %% [markdown]
# Let's verify the presence of outliers:

# %%
DisMap[selected_variables].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# The presence of outliers forces us to choose a robust transformation to produce columns ready for clustering techniques:
#
# $$Z_{\text{robust}} = \frac{X - \text{Median}}{\text{MAD}}$$
#
# 1.  **Median:** Unlike the mean, the median is minimally affected by outliers.
# 2.  **Median Absolute Deviation (MAD):** This is a robust measure of statistical dispersion. It is calculated by finding the median of the absolute deviations from the median: $\text{MAD} = \text{Median}(|X - \text{Median}|)$.
#
# I will use **mad()** from scipy with **scale='normal'**. The `scale='normal'` argument ensures the resulting MAD value is scaled to be comparable to the standard deviation ($\sigma$). This ensures your new robust scores are on a familiar scale (most values between $-3$ and $+3$) and are suitable for our clustering algorithm.
#
# Notice regression **needs not** this standardization.

# %%
import pandas as pd
import numpy as np
from scipy.stats import median_abs_deviation as mad

# --- Function to Perform Robust Standardization (Z-score via Median and MAD) ---
def robust_score(series):
    # 1. Calculate the Median
    median_val = series.median()
    # 2. Calculate the Median Absolute Deviation (MAD)
    mad_val = mad(series, scale='normal') #for comparability with Zs
    # 3. Apply the Robust Formula
    return (series - median_val) / mad_val

# %% [markdown]
# Let's rename the variables to used during clustering:

# %%
deficit_cols = ['Educ_sec_incomp2019_pct','NBI2017_pct', 'Viv_sin_serv_hig2017_pct']

clusterNames=['Education_deficit','BasicNeeds_deficit','Sanitation_deficit']
DisMap[clusterNames]=DisMap[deficit_cols].apply(robust_score)
DisMap[clusterNames]
# Out:
#       Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# 0             -1.251137           -1.124150           -0.721547
# 1              0.378949           -0.098003            1.043106
# 2              0.044169           -0.524603           -0.258816
# 3             -0.887730            2.023469            4.352812
# 4             -0.432460           -0.386246           -0.078429
# ...                 ...                 ...                 ...
# 1866          -0.496023            0.000000           -0.133329
# 1867          -0.313561            0.714844            1.905826
# 1868          -0.673526           -0.380481           -0.235287
# 1869          -0.670427            0.167181           -0.250973
# 1870          -1.288417           -0.397776            0.298030
#
# [1871 rows x 3 columns]

# %%
# as a result:
DisMap[clusterNames].corr()
# Out:
#                     Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# Education_deficit            1.000000            0.429768            0.201020
# BasicNeeds_deficit           0.429768            1.000000            0.662596
# Sanitation_deficit           0.201020            0.662596            1.000000

# %% [markdown]
# Let's rename the original variables for regression section:

# %%
#prepare the dict
regressionNames=[col+'_pct' for col in clusterNames]
changes={old:new for old,new in zip(deficit_cols,regressionNames)}
changes
# Out:
# {'Educ_sec_incomp2019_pct': 'Education_deficit_pct',
#  'NBI2017_pct': 'BasicNeeds_deficit_pct',
#  'Viv_sin_serv_hig2017_pct': 'Sanitation_deficit_pct'}

# %%
DisMap.rename(columns=changes,inplace=True)

# %% [markdown]
# ### The SEED
#
# Several functions will use some random process. I will set a seed here, that you have use should you wnat to get the same results I got.

# %%
import numpy
RANDOM_SEED = 12345
numpy.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### Conventional Clustering
#
# Conventional clustering is a basic machine learning technique used to group a set of data points into clusters so that points within the same cluster are more similar to each other than to those in other clusters. Think of it as sorting objects into piles based on how alike they are.
#
# In this case, I will use the three variables to create clusters of **districts**. There are several options you may have seen before, like KMeans,KMedoids, and Hierarchical (divissive/agglomerative).

# %% [markdown]
# #### KMeans
#
# We can easily compute them like this:

# %%
from sklearn.cluster import KMeans

K_target = 5

# as simple as:
DisMap['deficit_k5'] = KMeans(n_clusters=K_target).fit_predict(DisMap[clusterNames])

# %%
# see distribution of districts
DisMap["deficit_k5"].value_counts()
# Out:
# deficit_k5
# 3    662
# 1    514
# 2    360
# 4    207
# 0    128
# Name: count, dtype: int64

# %% [markdown]
# #### Profiling
# We could try to find the pattern that created the clusters:

# %%
DisMap.groupby("deficit_k5")[clusterNames].mean()
# Out:
#             Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# deficit_k5
# 0                    0.589119            2.272034            3.725012
# 1                    0.709835           -0.116890           -0.065597
# 2                   -0.013254            0.643343            1.521937
# 3                   -0.728948           -0.663483           -0.405225
# 4                    0.892551            1.600907            0.035198

# %% [markdown]
# Keepig in mind that meaning a score of **0** is the national median, a **positive** score indicates a **higher deficit (worse)** than the median, and a **negative** score indicates a **lower deficit (better)** than the median; let's propose an interpretation, and naming, of our five distinct clusters:
#
#
# | Cluster | Label | Reason |
# |---------|-------|---------|
# | **0** | `Low Deficits - Well Performing` | All deficits negative (below average) |
# | **1** | `Sanitation Crisis Area` | Extreme sanitation deficit (+1.46) |
# | **2** | `Severe Multi-Dimensional Crisis` | All deficits highly positive (worst) |
# | **3** | `Education Challenge Area` | Only education deficit is positive |
# | **4** | `Education & Basic Needs Struggle` | High education & basic needs deficits |
#
# **Quick interpretation:**
# - **Cluster 0**: Best areas (intervention not urgent)
# - **Cluster 2**: Worst areas (need immediate comprehensive intervention)
# - **Clusters 1,3,4**: Need targeted interventions for specific deficits

# %% [markdown]
# ## Regionalization: Spatial Clustering
#
# Regionalization is the process of **clustering cases into contiguous regions** based on shared characteristics. In our work, the goal is to create socio-economic zones where districts within a zone are similar to each other and geographically connected.
#
# Conventional clustering (like KMeans above) group districts based only on their **deficit scores** (Education, NBI, Sanitation), but you see  a messy, fragmented map.  **Spatial Clustering (Regionalization) will wotk differently following:**
#
# 1.  **Attribute Similarity:** It still requires districts to have similar socio-economic **deficits** (based on your Robust Z-scores).
# 2.  **Contiguity Constraint:** It adds the rule that a district can **only be grouped with a neighbor it physically shares a border with**.
#
# By enforcing this contiguity, spatial clustering ensures that the final $K=5$ groups  are not scattered patches but are **contiguous, policy-relevant territorial blocks**.
#
# This way Spatial clustering tries building regions that are both **statistically coherent** (similar deficit profiles) and **geographically coherent** (connected in space). A good regionalization  makes the results useful for regional planning, resource allocation, and targeted policy intervention.

# %% [markdown]
# Let's compute the neigborhood matrix:

# %%
# for mos cases except spatial kmeans
peru_perim_graph = Graph.build_contiguity(DisMap, by_perimeter=True)
peru_perim_graph=peru_perim_graph.transform("r")

# for spatial kmeans
from libpysal.weights import W # Import W for the conversion
peru_perim = peru_perim_graph.to_W()
peru_perim.transform = "r"

# %% [markdown]
# Notice we have two matrices:

# %%
type(peru_perim_graph),type(peru_perim)
# Out:
# (libpysal.graph.base.Graph, libpysal.weights.weights.W)

# %% [markdown]
# They have the same information, but they are different data structures.

# %% [markdown]
# ### 1. The K-means with contiguity: Regional K-Means Heuristic
#
# We can easily get these clusters using (notice here we use **peru_perim**):

# %%
from spopt.region import RegionKMeansHeuristic as RKMeans

RKMeans_model = RKMeans(data=DisMap[clusterNames].values, 
                        n_clusters=K_target,
                        w=peru_perim,drop_islands=True)
# computing
RKMeans_model.solve()

# %% [markdown]
# From here, we can add that column to our data:

# %%
DisMap['deficit_k5R'] = RKMeans_model.labels_

# %% [markdown]
# ### 2. The Swapping game: AZP (A Priori Zoning Problem)
#
# AZP is one of the earliest and most direct algorithms for spatial clustering. We can easily compute it like this (notice **w=peru_perim_graph**)

# %%
from spopt.region import AZP

azp_model = AZP(
    gdf=DisMap,
    w=peru_perim_graph,
    attrs_name=clusterNames,
    n_clusters=K_target,
    random_state=RANDOM_SEED)
# computing
azp_model.solve()

# %% [markdown]
# New column with labels:

# %%
DisMap['deficit_azpR'] = azp_model.labels_

# %% [markdown]
# ### 3. The Smart gardener: Skater
#
# The "Spatial 'K'luster Analysis by Tree Edge Removal" is avery interesting model based on the Minimum Spanning Tree (take a look: [MST](https://colab.research.google.com/drive/1CQwjJR6i_3X_8izLsDt-TPfbLtpCnN5T?usp=sharing)).
#
# We can easily compute this regression like this:

# %%
from spopt.region import Skater

skater_model = Skater(
    gdf=DisMap,
    w=peru_perim_graph,
    attrs_name=clusterNames,
    n_clusters=K_target
)
# computing
skater_model.solve()

# %% [markdown]
# The cluster as a new column:

# %%
DisMap['deficit_skaterR'] = skater_model.labels_

# %% [markdown]
# ## Clustering vs Regionalization
#
# ### Geographical Coherence:
#
# Here we can compute two measures of **COMPACTNESS**
#
# * **The isoperimetric quotient (IPQ)**. This compares the area of the region to the area of a circle with the same perimeter as the region.
# * **Convex hull ratio (CHR)**. The CHR is simply the division of the area of the cluster by the area of its convex hull.

# %%
from esda import shape as compactness

# columns with cluster labels
cluster_types_to_evaluate = ["deficit_k5","deficit_k5R","deficit_azpR","deficit_skaterR"]

# List to store the results
means_IPQCHR = [] 

for cluster_type in cluster_types_to_evaluate:
    # 1.disolving for both
    regions = DisMap[[cluster_type, "geometry"]].dissolve(by=cluster_type) 
    
    # 2. Compute IPQ and CHR (at the dissolved regions level)
    ipqs = compactness.isoperimetric_quotient(regions)
    chullr = compactness.convex_hull_ratio(regions)

    # 3. Append the means to 'means_IPQCHR'
    means_IPQCHR.append((cluster_type, ipqs.mean(), chullr.mean()))

# Re-arrange the scores into a dataframe for display
colNames = ["cluster type", "Mean IPQ", "Mean CHR"]
comparisson_geo = pd.DataFrame(means_IPQCHR, columns=colNames).set_index("cluster type")

# %% [markdown]
# Both **Isoperimetric Quotient (IPQ)** and **Convex Hull Ratio (CHR)** are metrics used to assess the **spatial compactness** of a polygon (like a geographic region), but they quantify compactness based on different geometric ideals.

# %% [markdown]
# ### Statistical Coherence
#
# Here we can compute for HOMOGENEITY
# * The **Silhouette (SIL) Score**
#
# And for HETEROGENEITY
# * The  **Calinski-Harabasz (CH) Score**:

# %%
from sklearn import metrics

scores_CHSIL = []

for cluster_type in cluster_types_to_evaluate:
    ch_score = metrics.calinski_harabasz_score(
        DisMap[clusterNames],# using scaled variables
        DisMap[cluster_type])# using these labels
    sil_score = metrics.silhouette_score(
        DisMap[clusterNames],DisMap[cluster_type]) #same as above
    
    # appending 
    scores_CHSIL.append((cluster_type, ch_score,sil_score))


# re-arrange the scores into a dataframe for display
colNames=["cluster type", "CH score", "SIL score"]
comparisson_stat=pd.DataFrame(scores_CHSIL, columns=colNames).set_index("cluster type")

# %% [markdown]
# We have:

# %%
# Concatenate the two DataFrames column-wise (axis=1)
combined_df = pd.concat([comparisson_geo,comparisson_stat],axis=1)

### Define the two levels of the column MultiIndex

# Level 0 (Top Header): Groups the metrics
top_level = ['Geo Coherence'] * 2 + ['Stat Coherence'] * 2
# Level 1 (Metric Name): The original column names
bottom_level = combined_df.columns.tolist() 

# Create the MultiIndex
combined_df.columns = pd.MultiIndex.from_arrays([top_level, bottom_level])

# Display the resulting DataFrame
combined_df
# Out:
#                 Geo Coherence           Stat Coherence
#                      Mean IPQ  Mean CHR       CH score SIL score
# cluster type
# deficit_k5           0.006282  0.196964    1204.811460  0.327443
# deficit_k5R          0.042852  0.589774     108.189487 -0.033656
# deficit_azpR         0.019085  0.419885     131.739950 -0.038092
# deficit_skaterR      0.134852  0.707410      85.945036 -0.114469

# %% [markdown]
# Considering that **deficit_k5** is the benchmark, we can conclude:

# %% [markdown]
# **Conventional Clustering ($\text{deficit\_k5}$)** is merely a mathematical grouping; it ignores spatial reality. For policy analysis, this method is useful only as a **benchmark** to understand the *maximum possible statistical coherence* achievable *without* geographic constraints.
#
# **Regionalization** (e.g., SKATER, AZP) is crucial because it ensures **usability** and **equity** in policy application:
#
# 1.  **Administrative Feasibility (Geo Coherence):** Policy implementation requires contiguous (connected) regions. You can't assign a regional development budget to a non-connected cluster. The extremely low **Geo Coherence** (Mean IPQ $0.006$, Mean CHR $0.197$) of $\text{deficit\_k5}$ confirms it is not an option for actual policy.
# 2.  **Addressing Spatial Heterogeneity:** Regionalization accounts for the fact that socio-economic phenomena are not randomly distributed; they often exhibit **spatial autocorrelation**. Grouping neighboring units that share similar statistical profiles (the goal of SKATER) provides regions where policies will have a consistent local impact.
# 3.  **Efficiency and Focus:** Regionalization reduces the complexity of analysis by creating a smaller number of clearly defined, coherent units, allowing policymakers to target interventions effectively.
#
# In policy, the statistical fit must be *subordinate* to the spatial requirement. **Contiguity and compactness** are **must-have constraints**, not desirable add-ons.
#
#
# > The Cost of Regionalizing
#
# The "cost" of regionalizing is the **sacrifice of statistical coherence** you must make to achieve **geographic coherence**. Your table quantifies this cost perfectly:
#
# * **Initial Stat Coherence (Benchmark $\text{deficit\_k5}$):** CH Score $1204.81$ and SIL Score $0.327$.
# * **The Cost:** Look at the drop in Stat Coherence when the geographic constraint is applied:
#     * **CH Score drops by $89\%$ to $93\%$** (down to $85 - 131$).
#     * **SIL Score drops from positive $(0.327)$ to negative** (indicating that the forced neighbors, while geographically appropriate, are not the ideal statistical neighbors).
#
# This cost is **unavoidable** because you are forcing the algorithm to ignore some optimal statistical groupings in order to respect the spatial boundary (the **"cost of swapping at the border"**). However, this cost is necessary to produce an **actionable, real-world policy unit**.
#
# > Is SKATER the Best in This Case?
#
# The decision hinges on choosing the method that achieves the **highest Geo Coherence** while maintaining an acceptable level of **Stat Coherence** (since all constrained methods already incur the necessary statistical "cost").
#
# | Method | Geo Coherence (Mean CHR) | Stat Coherence (CH Score) | Assessment |
# | :--- | :---: | :---: | :--- |
# | **SKATER** ($\text{deficit\_skaterR}$) | **0.707** (Highest) | 85.95 (Lowest) | **Best Shape:** Superiorly compact and cohesive. |
# | **K5R** ($\text{deficit\_k5R}$) | 0.590 | 108.19 (Mid-range) | Moderate shape, less geographically logical than SKATER. |
# | **AZPR** ($\text{deficit\_azpR}$) | 0.420 (Lowest) | 131.74 (Highest constrained) | **Worst Shape:** High statistical fit but very irregular regions. |
#
# 1.  **SKATER Wins Geo Coherence:** The **Mean CHR of $0.707$** is significantly better than the next closest competitor ($\text{deficit\_k5R}$ at $0.590$). This means the SKATER regions are the most **compact** and **well-formed** regions, which is critical for administrative simplicity and public understanding.
# 2.  **SKATER's Stat Coherence is Acceptable:** While SKATER has the lowest CH score among the constrained methods, the difference between the constrained methods is marginal compared to the massive drop from the benchmark. All three constrained methods have paid the "cost of regionalizing." **SKATER provides the most usable geographic output for the shared statistical cost.**
#
# Then, **SKATER is the optimal method** because it prioritizes **Geo Coherence** (compactness and usability), delivering the **least convoluted** boundaries, a non-negotiable trait for effective policy regionalization.
#
# Let's do the profiling:

# %%
DisMap.groupby("deficit_skaterR")[clusterNames].mean()
# Out:
#                  Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# deficit_skaterR
# 0                        -0.116193            0.191358            0.662873
# 1                        -0.751879           -0.237336            0.153759
# 2                         0.507940            0.146497           -0.062674
# 3                         1.161997            1.634777            1.001277
# 4                        -1.033273           -1.225515           -0.839518

# %% [markdown]
# * **SKATER Cluster Profiling**
#
# *  **Cluster 0**
#     - **Education Deficit**: Slightly **below average** (−0.12) → better access to education.
#     - **Basic Needs Deficit**: **Above average** (+0.19) → moderate challenges in meeting basic needs (e.g., food, housing).
#     - **Sanitation Deficit**: **Highly above average** (+0.66) → significant sanitation issues.
#     ➡️ **Profile**: *Relatively educated but struggling with sanitation and, to a lesser extent, basic needs.*
#
# *  **Cluster 1**
#     - **Education Deficit**: **Well below average** (−0.75) → strong educational access.
#     - **Basic Needs Deficit**: **Below average** (−0.24) → better-than-average fulfillment of basic needs.
#     - **Sanitation Deficit**: **Slightly above average** (+0.15) → minor sanitation challenges.
#     ➡️ **Profile**: *Overall resilient region with strong education and basic needs coverage; minor sanitation gaps.*
#
# * **Cluster 2**
#     - **Education Deficit**: **Above average** (+0.51) → notable education gaps.
#     - **Basic Needs Deficit**: **Slightly above average** (+0.15) → moderate basic needs challenges.
#     - **Sanitation Deficit**: **Slightly below average** (−0.06) → marginally better sanitation.
#     ➡️ **Profile**: *Struggles primarily with education, with modest challenges in basic needs; sanitation is relatively less problematic.*
#
# * **Cluster 3**
#     - **Education Deficit**: **Very high** (+1.16) → severe education deficits.
#     - **Basic Needs Deficit**: **Extremely high** (+1.63) → critical lack of basic necessities.
#     - **Sanitation Deficit**: **High** (+1.00) → major sanitation issues.
#     ➡️ **Profile**: *Most vulnerable cluster—facing severe, multi-dimensional deprivation across all indicators.*
#
# * **Cluster 4**
#     - **Education Deficit**: **Very low** (−1.03) → excellent educational access.
#     - **Basic Needs Deficit**: **Very low** (−1.23) → strong fulfillment of basic needs.
#     - **Sanitation Deficit**: **Low** (−0.84) → good sanitation infrastructure.
#     ➡️ **Profile**: *Most privileged cluster—consistently outperforms average across all dimensions.*
#
# **Policy Recommendations**
# - **Cluster 3**: Requires urgent, integrated interventions (education, food security, WASH programs).
# - **Cluster 0 & 2**: Focus on sanitation infrastructure and educational support, respectively.
# - **Cluster 1**: Minor sanitation improvements could make it a model region.
# - **Cluster 4**: Monitor to sustain advantages; potential donor region for peer-learning initiatives.

# %%
forRecode = {
    0: "1.Sanitation-Challenged",
    1: "2.Stable",
    2: "3.Education-Deprived",
    3: "4.Acute Deprivation",
    4: "5.Prosperous"
}

DisMap.replace({"deficit_skaterR":forRecode},inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming DisMap is your GeoDataFrame with the cluster columns
cluster_types = ["deficit_k5", "deficit_k5R", "deficit_azpR", "deficit_skaterR"]
titles = ["K-Means", "RegionKMeans", "AZP", "SKATER"]

fig, axes = plt.subplots(2, 3, figsize=(16, 12))
axes = axes.flatten()

# Find the maximum number of clusters across all methods for consistent coloring
max_clusters = max([DisMap[ct].nunique() for ct in cluster_types])

for i, (cluster_type, title) in enumerate(zip(cluster_types, titles)):
    # Plot with consistent colormap
    DisMap.plot(column=cluster_type, 
                ax=axes[i],
                categorical=True,
                legend=True,
                cmap='tab10',  # Consistent colors
                edgecolor=None,
                linewidth=0.3)
    
    axes[i].set_title(f'{title}', fontsize=14, fontweight='bold')
    axes[i].set_axis_off()

plt.suptitle('Comparison when K is 5\n (color can not be compared without profiling)', 
             fontsize=16, fontweight='bold',color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conventional Regression
#
#
# Let's represent this model:
#
# $$\text{BasicNeeds\_deficit\_pct} = \beta_0 + \beta_1 (\text{Sanitation\_deficit\_pct}) + \beta_2 (\text{Education\_deficit\_pct}) + \epsilon$$
#
# The model attempts to predict the **Percentage of Population with Unmet Basic Needs (NBI)** using the **Percentage with Completed High-School Education** and the **Percentage of Households Lacking Sanitation**.

# %%
from pysal.model import spreg

dep_var_name='BasicNeeds_deficit_pct'
ind_vars_names=['Sanitation_deficit_pct', 'Education_deficit_pct']

argsRegre=dict(
    y=DisMap[dep_var_name], # Dependent variable
    x=DisMap[ind_vars_names], # Independent variables
    name_y=dep_var_name, # Dependent variable name
    name_x=ind_vars_names, # Independent variable name
    name_ds='DisMap') # name of data set

ols_model = spreg.OLS(**argsRegre)
    

ols_model.output
# Out:
#                 var_names coefficients   std_err    zt_stat prob
# 0                CONSTANT    11.230543  0.876661  12.810583  0.0
# 1  Sanitation_deficit_pct     0.671289  0.018089  37.110163  0.0
# 2   Education_deficit_pct     0.359272  0.018809  19.100679  0.0

# %% [markdown]
# If we wish to compare this output with other regression models, you may use:
#
# * For **non-nested models**:

# %%
ols_model.ar2
# Out:
# np.float64(0.5301902863255213)

# %%
ols_model.aic
# Out:
# np.float64(14775.887907529901)

# %%
ols_model.logll # Log Likelihood
# Out:
# np.float64(-7384.9439537649505)

# %%
np.sqrt(ols_model.sig2) # S.E. of Regression
# Out:
# np.float64(12.539968014149354)

# %% [markdown]
# * For **nested models**:

# %%
ols_model.f_stat[0],ols_model.f_stat[1]<0.05
# Out:
# (np.float64(1056.167450321906), np.True_)

# %% [markdown]
# | Test | Null Hypothesis ($H_0$) | Comparison Method | Key Concept |
# | :--- | :--- | :--- | :--- |
# | **F-statistic** | All $X$ coefficients are zero (comparing the model to a null model with only a constant). | Reject $H_0$ if **$p$-value** is low. | **Overall Model Significance** |
#
# In simple terms, when comparing different models:
#
# > The model with the **lowest AIC**, the **highest Adjusted $R^2$**, and the **lowest S.E. of Regression** is generally preferred, given the **F-Statistics is significant**.

# %% [markdown]
# ### OLS diagnostics
#
# WE need to verify post-hoc if some issues arised that would weaken model usefulness.
#
# The object **ols_model** has key information on this:

# %%
# is there collinearity?
ols_model.mulColli>=30
# Out:
# False

# %%
# is the normality?
ols_model.jarque_bera['pvalue']>0.05
# Out:
# np.False_

# %%
# is there homocedasticity?
ols_model.koenker_bassett['pvalue']>0.05
# Out:
# np.False_

# %% [markdown]
# If we stay with conventional regression (OLS), we should deal with lack of normality and homocedasticity.

# %% [markdown]
# ### Spatial Regression need?
#
# Let's re run the previous code, but requesting **spatial disgnostics**, for that we input the adjacency matrix (peru_perim_graph)

# %%
W_info=dict(
    w=peru_perim_graph,       # REQUIRED: Defines neighbor relationships for spatial diagnostics
    name_w='peru_perim_graph') # Name of the weights matrix

argsRegre_W=argsRegre.copy()
argsRegre_W.update(W_info)

ols_model_with_W = spreg.OLS( **argsRegre_W,                 
                   spat_diag=True,         # generates spatial tests)
                   robust='white'          # essential to deal with OLS diagnostic problems
                   )

# %% [markdown]
# Given we request spatial diagnostics (post-hoc), let's apply the **Durbin Joint Test**:

# %%
# Do any of the regression terms (X, Y, error) is being affected by behavior of neighbors
ols_model_with_W.lm_spdurbin[1]<0.05
# Out:
# np.True_

# %% [markdown]
# The significance of the Joint test for SDM (your result: $p < 0.05$) confirms a crucial point:
#
# >The OLS model is statistically wrong (misspecified). A spatial model is needed. This is telling us that location is playing in at least one of these terms: X (independent variables), Y (dependent variables), $\epsilon$ (error term).
#
# These are possible regression models for each case:

# %% [markdown]
# * **SAR**: The value of Y in neighboring locations directly affects your Y.

# %%
ols_model_with_W.rlm_lag[1]<0.05
# Out:
# np.False_

# %% [markdown]
# * **SEM**: A location's error is dependent on its neighbors' errors, meaning unobserved influences spread across space

# %%
ols_model_with_W.rlm_error[1]<0.05
# Out:
# np.True_

# %% [markdown]
# * **SLX**: The values of X in neighboring locations affect your Y.

# %%
ols_model_with_W.rlm_wx[1]<0.05
# Out:
# np.True_

# %% [markdown]
# Let's start the journey! (SAR was not good, but will be part of the journey).

# %% [markdown]
# ## Spatial Regression: SAR
#
# The Spatial Autoregressive (SAR) model can be computed like this:

# %%
SAR_model = spreg.GM_Lag(
    **argsRegre_W,
    spat_impacts='simple', 
    robust='white') # we knew there is Heteroskedasticity

# %% [markdown]
# Now, let's see the regression coefficients:

# %%
SAR_model.output # this is rho: W_BasicNeeds_deficit_pct
# Out:
#                   var_names coefficients   std_err    zt_stat      prob
# 0                  CONSTANT     9.767108  1.048124   9.318655       0.0
# 1    Sanitation_deficit_pct     0.653007  0.018482  35.331866       0.0
# 2     Education_deficit_pct      0.33859  0.023903  14.165268       0.0
# 3  W_BasicNeeds_deficit_pct     0.069026  0.035413   1.949188  0.051273

# %% [markdown]
# The **W\_BasicNeeds\_deficit\_pct**, is the estimated **Spatial Autoregressive Parameter ($\mathbf{\rho}$ or *rho*)** for the SAR model. This $\mathbf{\rho}$ captures the existence of **Spillover Effect**:
#
# > **POSITIVE SPILLOVER:** The positive value ($\mathbf{0.069}$) indicates **positive spatial autocorrelation** in the dependent variable. That is, an increase in the average `BasicNeeds_deficit_pct` in neighboring 'distrito' leads to an increase in the `BasicNeeds_deficit_pct` in the current 'distrito', holding all other factors constant. The magnitude is relatively small ($\mathbf{0.069}$), meaning the spillover effect is not very strong. Morevover, the **$p$-value:** $\mathbf{0.051273}$ is just barely above the conventional $0.05$ significance level.
#
# At a strict $\alpha=0.05$ level, you would **fail to reject the null hypothesis ($H_0: \rho = 0$)**, suggesting the spatial lag term is **not statistically significant**.

# %% [markdown]
# * **Diagnostics for remaining Spatial Dependence**:

# %%
#Anselin-Kelejian Test
SAR_model.ak_test, SAR_model.ak_test[1]<0.05
# Out:
# ((np.float64(132.56784792511712), np.float64(1.1239891603541386e-30)),
#  np.True_)

# %% [markdown]
# Then,
#
# > **The SAR model has NOT fully corrected the spatial dependence problem, as the model residuals are still spatially correlated.**

# %% [markdown]
# * **Interpretation of coefficients**
#
# In a SAR model, the coefficients ($\beta$) are not direct marginal effects because a change in $X$ in one location affects the dependent variable in all other locations (due to the feedback loop of $\rho WY$). Therefore, the impacts are broken down:

# %%
from spreg.sputils import spmultiplier

# Compute multipliers
impacts = spmultiplier(peru_perim_graph, SAR_model.rho[0])

# Get relevant betas (drop intercept and rho)
betas = SAR_model.betas[1:-1].flatten()

# Build impact table
effects_df = pd.DataFrame({
    'Variable': ind_vars_names,
    'Direct': betas * impacts['adi'],
    'Indirect': betas * impacts['aii'],
    'Total': betas * impacts['ati']
})

# here you are
effects_df
# Out:
#                  Variable    Direct  Indirect     Total
# 0  Sanitation_deficit_pct  0.653007  0.048416  0.701423
# 1   Education_deficit_pct  0.338590  0.025104  0.363694

# %% [markdown]
# In our case, the **SAR** model assumes that the level of unsatisfied needs in each city depends not only on its own socioeconomic deficits, but also on the **levels of unsatisfied needs in neighboring cities** (through ( WY ) and ρ).
#
# Because ρ = 0.069 (small but positive), there **might be some spatial dependence**, meaning deprivation in one city tends to “echo” in its neighbors — but modestly.
#
# **Sanitation_deficit_pct**
#
# * **Direct effect (0.653):**
#   If the share of households without adequate sanitation in a city increases by **1 percentage point**, the share of the population with *unsatisfied needs* in that city increases by **0.65 percentage points**, on average.
#   → This captures the *within-city* marginal impact.
#
# * **Indirect effect (0.048):**
#   The same 1-point increase also raises unsatisfied needs in *neighboring cities* by about **0.05 percentage points**, on average, due to spatial spillovers.
#   → Poor sanitation in one city slightly worsens deprivation nearby (perhaps via migration, shared infrastructure, or regional contagion of poverty).
#
# * **Total effect (0.701):**
#   Overall, each additional point of sanitation deficit in one city leads to about **0.7 percentage points more unsatisfied needs** in the regional system (the city + its neighbors).
#
#
# **Education_deficit_pct**
#
# * **Direct effect (0.339):**
#   A 1-point increase in the local education deficit raises unsatisfied needs locally by **0.34 points**, on average.
#
# * **Indirect effect (0.025):**
#   It also raises deprivation in nearby cities by **0.025 points**, on average.
#
# * **Total effect (0.364):**
#   Overall regional effect ≈ **0.36 percentage points** increase in unsatisfied needs for each point increase in education deficit.
#
# What the pattern tells us:
#
# * **Local impacts dominate:** Most of the effect of social deficits operates **within each city**, as shown by the ratio of Direct to Total effects (≈ 92–93 % for both variables). This indicates that the bulk of deprivation is locally determined, with limited interdependence among neighboring cities.
#
# * **Spillovers are small but systematic:** The remaining 7–8 % of the total effect reflects **spatial spillovers**, meaning that a city’s deficits slightly exacerbate unsatisfied needs in adjacent areas. This pattern is consistent with **spatial diffusion of poverty** and the emergence of **regional inequality traps**, where deprivation in one locality reinforces that of nearby ones.
#
# * **Comparatively:** **Sanitation deficits** have roughly **twice the total impact** of education deficits on unsatisfied needs (0.70 vs. 0.36). This suggests that deficits in **basic infrastructure and public services** play a more decisive role in shaping aggregate social deprivation than shortfalls in education.

# %% [markdown]
# ## Spatial Regression: SEM
#
#
# The **Spatial Error Model (SEM)** can be computed like this:

# %%
# GM - uses a Generalized Moments (GM) estimator that is robust to heteroskedasticity.
SEM_model = spreg.GM_Error_Het(**argsRegre_W)

# %% [markdown]
# Let's check the GoF first:

# %%
SEM_model.pr2>ols_model.ar2
# Out:
# np.False_

# %% [markdown]
# Now the regression coefficients:

# %%
SEM_model.output
# Out:
#                 var_names coefficients   std_err    zt_stat prob
# 0                CONSTANT    16.291147  1.150997  14.153945  0.0
# 1  Sanitation_deficit_pct     0.744934  0.014981  49.726259  0.0
# 2   Education_deficit_pct     0.203697  0.021447   9.497633  0.0
# 3                  lambda     0.780674  0.018528   42.13485  0.0

# %% [markdown]
# The estimated spatial error coefficient of $\lambda = \mathbf{0.781}$ indicates a very strong spatial dependence in the unobserved component of the model. Substantively, this means that an unexplained shock in one district induces, on average, a response equal to about 78% of that shock’s magnitude in the composite error of its neighboring districts, as defined by the spatial weights matrix W. In other words, local unobservables are highly correlated across space: when one area experiences higher-than-predicted Basic Needs Deficit, nearby areas tend to exhibit nearly proportional residual increases. Such a large and significant value confirms that the residual process is strongly autoregressive, and that controlling for spatial dependence through the SEM specification is essential.
#
# * **Heteroskedasticity-Robust Coefficients**
#
# The standard errors and z-statistics here are corrected for both spatial error and heteroskedasticity, making them the **most reliable estimates so far**.

# %% [markdown]
# ## Spatial Regression: SLX
#
# The Spatial Lag of X (SLX) model cam be computed like this:

# %%
slx_model = spreg.OLS(**argsRegre_W,
    spat_diag=True,
    slx_lags=1,robust="white"
)
slx_model.output
# Out:
#                   var_names coefficients   std_err    zt_stat      prob
# 0                  CONSTANT     7.200011  1.017128   7.078765       0.0
# 1    Sanitation_deficit_pct     0.724735  0.020432  35.471414       0.0
# 2     Education_deficit_pct     0.203485  0.030228    6.73176       0.0
# 3  W_Sanitation_deficit_pct    -0.112312  0.031362  -3.581161  0.000351
# 4   W_Education_deficit_pct     0.269385  0.037319   7.218526       0.0

# %% [markdown]
# Given that SLX models:
#
#
# $$
# y = X\beta + WX\theta + \varepsilon
# $$
#
# * **Direct effect** → the impact of a variable in district *i* on its own outcome (*β*).
# * **Indirect effect (spillover)** → the impact of that variable in *neighboring districts* on district *i*’s outcome (*θ*).
# * **Total effect** → the sum (*β + θ*), representing the **overall regional impact** of a change in that variable.
#
#
# | Variable               | Direct effect (β) | Indirect effect (θ) | Total effect (β + θ) | Significance  |
# | ---------------------- | ----------------: | ------------------: | -------------------: | ------------- |
# | **Sanitation deficit** |            0.7247 |             −0.1123 |           **0.6124** | All p < 0.001 |
# | **Education deficit**  |            0.2035 |             +0.2694 |           **0.4729** | All p < 0.001 |
#
# We see that:
#
# > **Direct effects** show that both sanitation and education deficits significantly increase local deprivation: a one-unit rise in sanitation deficit raises Basic Needs Deficit by **0.725 points**, while a comparable increase in education deficit raises it by **0.203 points**.
# >
# > **Indirect (spillover) effects** indicate that neighboring conditions also matter. Higher **education deficits in adjacent districts** raise local deprivation (+0.269), revealing a **positive spatial spillover**—deprivation clusters regionally through educational disadvantage. Conversely, **neighboring sanitation deficits** exhibit a **negative spillover** (−0.112), suggesting **spatial compensation or policy substitution**, where areas surrounded by worse sanitation conditions may receive offsetting resources or attention.
# >
# > **Total effects** confirm that sanitation deficits remain the strongest overall determinant (0.612), but **educational deficits—local and neighboring combined—exert nearly half as much total impact (0.473)**, underscoring the regional diffusion of educational deprivation.

# %% [markdown]
# * Are we missing something given we have controlled spatial dependence in X?

# %%
# need to further control error?
slx_model.rlm_error[1]<0.05
# Out:
# np.False_

# %%
# need to further control Y?
slx_model.rlm_lag[1]<0.05
# Out:
# np.True_

# %% [markdown]
# ## Spatial Regression: SLX-Error
#
#
# The Spatially Lagged X with Spatial Error Model (**SLX-Error Model**) is a hybrid spatial regression model designed to account for two distinct sources of spatial dependence simultaneously:
#
# 1.  **Exogenous Spatial Interaction (The SLX Component):** The influence of independent variables ($\mathbf{X}$) in neighboring areas directly affecting the dependent variable ($\mathbf{Y}$) in the local area.
# 2.  **Unmodeled Spatial Dependence (The Error Component):** The spatial clustering of unobserved factors that are not captured by the independent variables, which shows up in the error term.
#
# The SLX-Error model essentially takes the standard **Spatial Error Model (SEM)** and adds the **Spatially Lagged X ($\mathbf{W X}$) terms**.
#
# The SLX-Error model is defined by the following two equations:
#
# $$
# \begin{aligned}
# \mathbf{Y} &= \mathbf{X}\boldsymbol{\beta} + \mathbf{W X}\boldsymbol{\theta} + \boldsymbol{\mu} \\
# \boldsymbol{\mu} &= \lambda \mathbf{W}\boldsymbol{\epsilon} + \boldsymbol{\epsilon}
# \end{aligned}
# $$
#
#
# | Term | Description | Role in the Model |
# | :--- | :--- | :--- |
# | $\mathbf{W X}\boldsymbol{\theta}$ | **Spatially Lagged Independent Variables (SLX)** | Captures **exogenous spillovers**. For example, your basic needs deficit is affected by your neighbor's sanitation deficit. |
# | $\lambda \mathbf{W}\boldsymbol{\epsilon}$ | **Spatially Autocorrelated Error Term** | Captures **unobserved factors** that are spatially clustered (e.g., shared unmeasured infrastructure or regional policy effects). |
#
# Key Advantages and Interpretation:
#
# * **Exogenous Spillover:** The $\mathbf{W X}\boldsymbol{\theta}$ terms allow for the direct quantification and interpretation of **exogenous spillovers**. The coefficient $\boldsymbol{\theta}$ is interpreted directly: a change in a neighbor's $X$ leads to a $\theta$-unit change in your $Y$.
# * **Correction for Bias:** The $\lambda$ term ensures that the $\boldsymbol{\beta}$ and $\boldsymbol{\theta}$ coefficients are **unbiased and efficient** by clearing the residuals of spatial autocorrelation.
# * **Stability:** Crucially, the SLX-Error model **does not include the endogenous feedback loop ($\rho \mathbf{W Y}$)**. This makes it a structurally stable model, avoiding the instability issues (like $\rho > 1$) that you encountered with the General Moments SDM.
#
# The SLX-Error model is often used when diagnostics strongly point to both **error dependence** and **exogenous spillovers**, and when the endogenous feedback ($\rho \mathbf{W Y}$) is found to be either insignificant or unstable.

# %%
from pysal.model.spreg import GM_Error_Het

SLXE_model = GM_Error_Het(**argsRegre_W,
                          slx_lags=1              # Adds the W*X terms
                         )

SLXE_model.output
# Out:
#                   var_names coefficients   std_err    zt_stat      prob
# 0                  CONSTANT     13.17256  1.951204   6.750992       0.0
# 1    Sanitation_deficit_pct     0.734482  0.015613   47.04185       0.0
# 2     Education_deficit_pct     0.210654   0.02202   9.566289       0.0
# 3  W_Sanitation_deficit_pct    -0.084732  0.034307  -2.469789  0.013519
# 4   W_Education_deficit_pct     0.100745   0.03814   2.641454  0.008255
# 5                    lambda     0.770436  0.019314  39.890691       0.0

# %% [markdown]
# What do we have now?
#
# | Variable       | Interpretation                                                                                                                                                                                                                                                                                                                                             |
# | :------------- | :--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **λ (lambda)** | **Strong Spatial Error Dependence:** λ = 0.770 is highly significant, indicating that unobserved shocks are strongly spatially correlated across districts. Disturbances in one area propagate with roughly 77% of their strength to neighboring districts through latent regional forces (e.g., shared policies, institutions, environmental conditions). |
#
# **Core Direct Effects ($X\boldsymbol{\beta}$)**
#
# | Variable                   | Interpretation                                                                                                                                                                           |
# | :------------------------- | :--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Sanitation_deficit_pct** | **Dominant Local Driver:** A 1-unit increase in a district’s sanitation deficit increases its Basic Needs Deficit by 0.73 units, confirming sanitation as the strongest local predictor. |
# | **Education_deficit_pct**  | **Significant Local Effect:** A 1-unit increase in a district’s education deficit raises its Basic Needs Deficit by 0.21 units.                                                          |
#
# **Exogenous Spillover Effects ($WX\boldsymbol{\theta}$)**
#
# | Variable                     | Interpretation                                                                                                                                                                                                   |
# | :--------------------------- | :--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **W_Sanitation_deficit_pct** | **Negative Spillover (Rivalry):** Higher sanitation deficits in neighboring districts are associated with a **lower** local Basic Needs Deficit, suggesting competitive or compensatory allocation of resources. |
# | **W_Education_deficit_pct**  | **Positive Spillover (Contagion):** Higher education deficits among neighbors increase local deprivation, indicating shared regional vulnerability through education systems or social conditions.               |
#
# **Synthesis**
#
# > The SLX–Error model demonstrates that the spatial dynamics of Basic Needs Deficit are driven by two complementary mechanisms: (1) **strong structural clustering** (λ) through unobserved, spatially correlated forces, and (2) **contrasting exogenous spillovers** (WX) where sanitation exhibits a rivalry effect and education exhibits a contagion effect. Together, these findings underscore the importance of accounting for both latent regional factors and observable neighbor effects in understanding deprivation.
#
# These results highlight that addressing Basic Needs Deficit in "a distrito" requires a **spatially coordinated approach**. Policies targeting sanitation should consider potential resource competition across neighboring districts, while interventions in education must account for **diffusive effects**, as deprivation in one district can exacerbate outcomes in its neighbors. Ignoring either the latent regional clustering or the observable spillovers could lead to ineffective or unevenly distributed interventions.

# %% [markdown]
# ## Spatial Regression: SAC
#
#
# The SAC model combines **two spatial processes**:
#
# $$
# y = \rho W y + X\beta + u, \quad u = \lambda W u + \varepsilon
# $$
#
# * $\rho$ → spatial lag of the dependent variable (W y)
# * $\lambda$ → spatial error (W u)
# * $\beta$ → coefficients on observed covariates (X)
#
# We can compute it like this:

# %%
sac_model =spreg.GM_Combo_Het(**argsRegre,
    w=peru_perim_graph,
    name_w='peru_perim_graph')

sac_model.output
# Out:
#                   var_names coefficients   std_err    zt_stat      prob
# 0                  CONSTANT    15.738191   2.10113   7.490347       0.0
# 1    Sanitation_deficit_pct     0.741984  0.015887  46.704395       0.0
# 2     Education_deficit_pct     0.211046  0.021525    9.80487       0.0
# 3  W_BasicNeeds_deficit_pct     0.009839  0.044581   0.220689  0.825335
# 4                    lambda       0.8027  0.024035  33.397797       0.0

# %% [markdown]
# We see that:
#
# | Variable                                             | Interpretation                                                                                                                                                                                                        |
# | :--------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Sanitation_deficit_pct (β = 0.742, p < 0.001)**    | **Dominant direct effect:** Local sanitation deficits strongly increase Basic Needs Deficit.                                                                                                                          |
# | **Education_deficit_pct (β = 0.211, p < 0.001)**     | **Significant direct effect:** Local education deficits also increase Basic Needs Deficit.                                                                                                                            |
# | **W_BasicNeeds_deficit_pct (ρ = 0.0098, p = 0.825)** | **Insignificant endogenous feedback:** Neighboring districts’ Basic Needs Deficit has **no measurable direct effect** on the local outcome. The dependent variable does not “diffuse” across neighbors in this model. |
# | **λ (lambda = 0.803, p < 0.001)**                    | **Strong spatial error dependence:** Unobserved shocks remain highly correlated across districts, indicating that latent regional factors drive much of the spatial structure.                                        |
# Then,
#
# > In the SAC model, the direct impact of local sanitation and education deficits remains robust. The spatial lag of the dependent variable (ρ) is essentially zero and non-significant, meaning that **deprivation does not propagate directly from one district to its neighbors**. Instead, the spatial autocorrelation is almost entirely in the **error term (λ = 0.803)**, reflecting **latent, regionally clustered factors** (e.g., shared policies, infrastructure, or environmental shocks) that are not captured by the observed covariates.

# %% [markdown]
# ## Spatial Regression: SDM
#
# The Spatial Durbin Model (SDM) is a model that combines the SAR structure with the **spatial lag of the independent variables** (the $WX\theta$ term).
#
# * **When to Use It (Diagnostics):** When both the **Robust LM (error)** and the **Robust LM WX test** are significant (as they are in our case).
# * **Model Structure:**
#     $$Y = \rho W Y + X\beta + W X \theta + \epsilon$$
#     * $\rho W Y$: Neighbors' deficit influences your deficit.
#     * $W X \theta$: Neighbors' **independent variables** (Sanitation and Education deficits) influence your deficit.
# * **Interpretation:** This model provides the **most complete picture of spillovers.** For example, not only does your neighbor's high Basic Needs Deficit affect yours ($\rho$), but your neighbor's high Education Deficit might also directly contribute to yours ($\theta$).
# * **SDM's Advantage:** If the true data generating process is an SDM, omitting the $WX$ term leads to an omitted variable bias in the SAR model. The SDM avoids this risk, making it the **safest starting point**.
#
# ---

# %%
sdm_model = spreg.GM_Lag(**argsRegre_W,
    slx_lags=1, robust="white"                          
)
sdm_model.output
# Out:
#                   var_names coefficients   std_err    zt_stat      prob
# 0                  CONSTANT     0.666529  1.159695   0.574745  0.565463
# 1    Sanitation_deficit_pct     0.761842  0.016511  46.141438       0.0
# 2     Education_deficit_pct     0.175288  0.021919   7.997127       0.0
# 3  W_Sanitation_deficit_pct    -0.778413  0.090416   -8.60927       0.0
# 4   W_Education_deficit_pct    -0.203502  0.063704  -3.194505  0.001401
# 5  W_BasicNeeds_deficit_pct     1.016223  0.132071   7.694527       0.0

# %% [markdown]
# This is what we have:
#
# **Endogenous Spatial Lag**
#
# | Variable                                            | Interpretation                                                                                                                                                                    |
# | :-------------------------------------------------- | :-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **W_BasicNeeds_deficit_pct (ρ = 1.016, p < 0.001)** | **Strong endogenous feedback:** A higher Basic Needs Deficit in neighboring districts strongly increases the local district’s deficit, reflecting outcome diffusion or contagion. |
#
# ---
#
# **Core Direct Effects ($X\beta$)**
#
# | Variable                   | Interpretation                                                                                                                                                           |
# | :------------------------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Sanitation_deficit_pct** | **Dominant local driver:** A 1-unit increase in the district’s own sanitation deficit raises its Basic Needs Deficit by 0.76 units, controlling for all spatial effects. |
# | **Education_deficit_pct**  | **Significant local effect:** A 1-unit increase in the district’s own education deficit raises its Basic Needs Deficit by 0.18 units.                                    |
#
#
#
# **Exogenous Spillover Effects ($W X\theta$)**
#
# | Variable                     | Interpretation                                                                                                                                                                                                                              |
# | :--------------------------- | :------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | **W_Sanitation_deficit_pct** | **Negative spillover (rivalry/compensation):** Higher sanitation deficits in neighboring districts **reduce** local Basic Needs Deficit, suggesting resources may be redirected to worse-off neighbors or compensatory dynamics.            |
# | **W_Education_deficit_pct**  | **Negative spillover (contagion moderation):** Higher education deficits in neighboring districts **slightly reduce** local deprivation, indicating some complex interaction, possibly due to shared educational interventions or policies. |
#
# The SDM results reveal that Basic Needs Deficit is shaped by **multiple spatial channels**:
#
# > 1. **Strong endogenous diffusion (ρ ≈ 1.02):** neighboring outcomes strongly influence local deprivation, indicating inter-district contagion.
# > 2. **Local deficits (β):** sanitation and education remain significant local drivers.
# > 3. **Contrasting exogenous spillovers (WX):** neighbor sanitation and education deficits have negative effects on local deprivation, suggesting compensatory dynamics or policy targeting.
# >
# > This underscores that both **outcome feedback** and **neighbor covariate effects** are crucial to understanding spatial patterns of deprivation, making SDM the most comprehensive model among those estimated.

# %% [markdown]
# * **Can we omit the exogenous control on WX?**

# %%
# Common Factor Hypothesis test
sdm_model.cfh_test[1]>0.05
# Out:
# np.True_

# %%
combo_model=spreg.GM_Combo_Het(**argsRegre,
    w=peru_perim_graph,slx_lags=1,
    name_w='peru_perim_graph')
print(combo_model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: SPATIALLY WEIGHTED 2SLS- GM-COMBO MODEL (HET) WITH SLX (GNSM)
# --------------------------------------------------------------------------------
# Data set            :      DisMap
# Weights matrix      :peru_perim_graph
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           6
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1865
# Pseudo R-squared    :      0.8026
# Spatial Pseudo R-squared:  0.1315
# N. of iterations    :           1                Step1c computed       :          No
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
# ...

# %%
# List all variables ending with "_model"
model_list = [name for name in globals() if name.endswith('_model')]
print(model_list)
# Out:
# ['RKMeans_model', 'azp_model', 'skater_model', 'ols_model', 'SAR_model', 'SEM_model', 'SLXE_model', 'sdm_model', 'slx_model', 'sac_model', 'combo_model']

# %%
# List of your model variable names
model_names = ['ols_model', 'SAR_model', 'SEM_model', 'SLXE_model', 
               'sdm_model', 'slx_model', 'sac_model', 'combo_model']

# Prepare a summary list
summary = []

for name in model_names:
    model = globals()[name]  # get the model object
    # Get AIC if available
    aic = getattr(model, 'aic', None)
    # Get pseudo R2
    r2 = getattr(model, 'r2', None)
    # Get spatial pseudo R2 if available
    pr2 = getattr(model, 'pr2', None)
    summary.append({
        'Model': name,
        'AIC': aic,
        'R2': r2,
        'Spatial Pseudo R2': pr2
    })

# Convert to DataFrame for nice display
import pandas as pd
summary_df = pd.DataFrame(summary)
print(summary_df)
# Out:
#          Model           AIC        R2  Spatial Pseudo R2
# 0    ols_model  14775.887908  0.530693                NaN
# 1    SAR_model           NaN       NaN           0.567819
# 2    SEM_model           NaN       NaN           0.512031
# 3   SLXE_model           NaN       NaN           0.535807
# 4    sdm_model           NaN       NaN           0.806578
# 5    slx_model  14714.263135  0.546868                NaN
# 6    sac_model           NaN       NaN           0.519571
# 7  combo_model           NaN       NaN           0.802604

# %% [markdown]
# * Combo includes:
#
#   * **Direct local effects (β)** → easy to interpret
#   * **Exogenous neighbor effects (WX → θ)** → observable spillovers
#   * **Endogenous outcome diffusion (ρ)** → neighbors’ outcomes influence local outcome
#   * **Latent spatial error (λ)** → unobserved clustering
#
# * The **problem**: all four effects operate simultaneously and partially absorb each other. For example:
#
#   * WX effects may **change sign or magnitude** once ρ is included.
#   * λ is smaller because some clustering is now captured by ρ + WX.
#
# * Result: it becomes **harder to say clearly “a 1-unit increase in neighbor’s deficit raises local deficit by X”** without qualifying that part of it is mediated through endogenous ρ.
#
# ---
#
# **Policy interpretation requires clarity of causal channels**
#
# * Policy recommendations usually focus on:
#
#   1. Local interventions → β effects
#   2. Neighbor effects → θ effects (contagion vs. rivalry)
#   3. Structural clustering → λ (less actionable, because unobserved)
#
# * Combo **mixes all channels**. If a policymaker asks:
#
#   > “Should we invest in sanitation locally, or intervene in neighboring districts?”
#
#   * You now have to **decompose direct β, θ, and ρ effects** to answer — much more complicated than in **SLX–Error**, where:
#
#     * β = local effects
#     * θ = exogenous spillovers
#     * λ = latent clustering (actionable only as awareness of hidden regional shocks)
#
# ---
#
# 3. **β coefficients remain interpretable, but θ + ρ interactions are tricky**
#
# * E.g., in your Combo model:
#
#   * W_Sanitation = –0.796 (negative)
#   * W_BasicNeeds (ρ) = 0.9 (positive)
#
# * Both effects act on neighbors, but they **partially offset each other**. A naïve policy interpretation could be misleading without decomposition.
#
# ---
#
# ### ✅ Summary
#
# | Model         | Interpretability                                   | Policy relevance                                                                    |
# | ------------- | -------------------------------------------------- | ----------------------------------------------------------------------------------- |
# | **SLX–Error** | High → clear β (local) + θ (neighbor) + λ (latent) | Easy to say which interventions matter locally or via neighbors                     |
# | **Combo**     | Moderate → β clear, but θ + ρ interact             | Harder to give simple recommendations because endogenous diffusion masks spillovers |
#
# **Bottom line:**
#
# > **Combo is statistically “fullest”, but SLX–Error is more transparent for policy because you can separate local, neighbor, and latent effects clearly.**
