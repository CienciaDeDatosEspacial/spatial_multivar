# %% [markdown]
# <center><img src="https://i.imgur.com/zRrFdsf.png" width="700"></center>
#
#
#
#
#
#
#
#
#
#
# # Multivariate Geostats: Beyond classical Clustering and Regression

# %% [markdown]
# ## Getting Ready

# %% [markdown]
# ### The Data
#
#
# Let's use the data from Peru previously seen:

# %%
import geopandas as gpd

peruDataLink="https://github.com/CienciaDeDatosEspacial/dataSets/raw/refs/heads/main/PERU/PeruMaps.gpkg"
DisMap=gpd.read_file(peruDataLink,layer='good_geom')

# %% [markdown]
# The "good_geom" layer is a new layer we had to use because it show no relevant topological issues (we had previously used one with some issues not detected).
#
# Rememeber this "good map" has isolates:

# %%
from libpysal.graph import Graph

DisMap_adjaceny=Graph.build_contiguity(DisMap)
DisMap_adjaceny.isolates
# Out:
# Index([51, 58], dtype='int64', name='focal')

# %% [markdown]
# Let's subset now, and avoid future warnings:

# %%
DisMap.drop(index=DisMap_adjaceny.isolates,inplace=True)
DisMap.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Preprocessing
#
# We have these columns:

# %%
DisMap.columns
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'ubigeo', 'Poblacion',
#        'IDH2019', 'Educ_sec_comp2019_pct', 'NBI2017_pct',
#        'Viv_sin_serv_hig2017_pct', 'geometry'],
#       dtype='object')

# %% [markdown]
# Let me select the columns we will use:

# %%
selected_variables = ['Educ_sec_comp2019_pct','NBI2017_pct', 'Viv_sin_serv_hig2017_pct']

# %% [markdown]
# Let's see the descriptives, paying attention to **range**:

# %%
DisMap[selected_variables].describe()
# Out:
#        Educ_sec_comp2019_pct  NBI2017_pct  Viv_sin_serv_hig2017_pct
# count            1871.000000  1871.000000               1871.000000
# mean               55.760485    38.586692                 17.074826
# std                15.738319    18.295127                 16.364994
# min                11.974433     1.100000                  0.000000
# 25%                44.451173    24.900000                  4.900000
# 50%                57.043976    35.300000                 12.100000
# 75%                68.220200    49.250000                 24.100000
# max                91.744878    99.400000                 96.500000

# %% [markdown]
# Let me check their monotony:

# %%
DisMap[selected_variables].corr()
# Out:
#                           Educ_sec_comp2019_pct  NBI2017_pct  \
# Educ_sec_comp2019_pct                  1.000000    -0.429768
# NBI2017_pct                           -0.429768     1.000000
# Viv_sin_serv_hig2017_pct              -0.201020     0.662596
#
#                           Viv_sin_serv_hig2017_pct
# Educ_sec_comp2019_pct                    -0.201020
# NBI2017_pct                               0.662596
# Viv_sin_serv_hig2017_pct                  1.000000

# %% [markdown]
# Clearly, 'Educ_sec_comp2019_pct' represents a diffent monotonic direction than the rest, because it measures a positive concept, while the others measure negative ones.
#
# Here, we can reverse the values of *Educ_sec_comp2019_pct*:

# %%
## from complete to 'incomplete'
DisMap['Educ_sec_incomp2019_pct']=100-DisMap['Educ_sec_comp2019_pct']

# %% [markdown]
# Let's verify the presence of outliers:

# %%
DisMap[selected_variables].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# The presence of outliers forces us to choose a robust transformation to produce columns ready for clustering techniques:
#
# $$Z_{\text{robust}} = \frac{X - \text{Median}}{\text{MAD}}$$
#
# 1.  **Median:** Unlike the mean, the median is minimally affected by outliers.
# 2.  **Median Absolute Deviation (MAD):** This is a robust measure of statistical dispersion. It is calculated by finding the median of the absolute deviations from the median: $\text{MAD} = \text{Median}(|X - \text{Median}|)$.
#
# I will use **mad()** from scipy with **scale='normal'**. The `scale='normal'` argument ensures the resulting MAD value is scaled to be comparable to the standard deviation ($\sigma$). This ensures your new robust scores are on a familiar scale (most values between $-3$ and $+3$) and are suitable for our clustering algorithm.
#
# Notice regression **needs not** this standardization.

# %%
import pandas as pd
import numpy as np
from scipy.stats import median_abs_deviation as mad

# --- Function to Perform Robust Standardization (Z-score via Median and MAD) ---
def robust_score(series):
    # 1. Calculate the Median
    median_val = series.median()
    # 2. Calculate the Median Absolute Deviation (MAD)
    mad_val = mad(series, scale='normal') #for comparability with Zs
    # 3. Apply the Robust Formula
    return (series - median_val) / mad_val

# %% [markdown]
# Let's rename the variables to used during clustering:

# %%
deficit_cols = ['Educ_sec_incomp2019_pct','NBI2017_pct', 'Viv_sin_serv_hig2017_pct']

clusterNames=['Education_deficit','BasicNeeds_deficit','Sanitation_deficit']
DisMap[clusterNames]=DisMap[deficit_cols].apply(robust_score)
DisMap[clusterNames]
# Out:
#       Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# 0             -1.251137           -1.124150           -0.721547
# 1              0.378949           -0.098003            1.043106
# 2              0.044169           -0.524603           -0.258816
# 3             -0.887730            2.023469            4.352812
# 4             -0.432460           -0.386246           -0.078429
# ...                 ...                 ...                 ...
# 1866          -0.496023            0.000000           -0.133329
# 1867          -0.313561            0.714844            1.905826
# 1868          -0.673526           -0.380481           -0.235287
# 1869          -0.670427            0.167181           -0.250973
# 1870          -1.288417           -0.397776            0.298030
#
# [1871 rows x 3 columns]

# %%
# as a result:
DisMap[clusterNames].corr()
# Out:
#                     Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# Education_deficit            1.000000            0.429768            0.201020
# BasicNeeds_deficit           0.429768            1.000000            0.662596
# Sanitation_deficit           0.201020            0.662596            1.000000

# %% [markdown]
# Let's rename the original variables for regression section:

# %%
#prepare the dict
regressionNames=[col+'_pct' for col in clusterNames]
changes={old:new for old,new in zip(deficit_cols,regressionNames)}
changes
# Out:
# {'Educ_sec_incomp2019_pct': 'Education_deficit_pct',
#  'NBI2017_pct': 'BasicNeeds_deficit_pct',
#  'Viv_sin_serv_hig2017_pct': 'Sanitation_deficit_pct'}

# %%
DisMap.rename(columns=changes,inplace=True)

# %% [markdown]
# ## The SEED
#
# Several functions will use some random process. I will set a seed here, that you have use should you wnat to get the same results I got.

# %%
import numpy
RANDOM_SEED = 12345
numpy.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### Conventional Clustering
#
# Conventional clustering is a basic machine learning technique used to group a set of data points into clusters so that points within the same cluster are more similar to each other than to those in other clusters. Think of it as sorting objects into piles based on how alike they are.
#
# In this case, I will use the three variables to create clusters of **districts**. There are several options you may have seen before, like KMeans,KMedoids, and Hierarchical (divissive/agglomerative).
#
#
# Let me use **KMeans**. This technique groups data points into **K number of clusters** by making the points in each cluster as similar as possible. You may have seen this in a previous course, but the simpler way to depict the process might be:
#
# > Imagine you have a big box of mixed-up balls of different colors. If you want 3 clusters, you will pick at random three balls, they will serve as leaders of the group. Then, you keep picking balls, every ball picked will gather with the first ones based on how similarity of color. However, you may find a color that produces a better separation, then you change the original leader. That will happen again and again, until you astonishly find your have bluesh, reddis and greenish balls in different groups.
#
# As you see, the algorithm is a process of **refinement**. It starts with a random guess and keeps improving the groups until it finds the most compact, natural-looking clusters possible.
#
#
# | Analogy Above | Formal K-Means Step | What Happens |
# | :--- | :--- | :--- |
# | **"I want 3 clusters"** | **1. Choose K** | Decide on the number of clusters. |
# | **"Pick 3 random balls as leaders"** | **2. Initialize** | Place K random centroids in the data. |
# | **"Balls gather with the leader they look most similar to"** | **3. Assign** | Assign each point to its nearest centroid, forming clusters. |
# | **"Find a better color and change the leader"** | **4. Update** | Calculate the new centroid (mean) for each cluster. |
# | **"That will happen again and again..."** | **5. Repeat** | Re-assign and update until centroids stabilize. |
#
# K-Means is an **unsupervised learning** algorithm used to find natural groupings in unlabeled data. It's great for exploration and pattern discovery.
#
# > **Remember:** You have to tell it how many clusters (K) you want in advance.

# %%
from sklearn.cluster import KMeans

K_target = 5

# as simple as:
DisMap['deficit_k5'] = KMeans(n_clusters=K_target).fit_predict(DisMap[clusterNames])

# %%
# see distribution of districts
DisMap["deficit_k5"].value_counts()
# Out:
# deficit_k5
# 2    663
# 1    516
# 4    357
# 3    207
# 0    128
# Name: count, dtype: int64

# %% [markdown]
# We could try to find the pattern that created the clusters:

# %%
DisMap.groupby("deficit_k5")[clusterNames].mean()
# Out:
#             Education_deficit  BasicNeeds_deficit  Sanitation_deficit
# deficit_k5
# 0                    0.589119            2.272034            3.725012
# 1                    0.707517           -0.113029           -0.061786
# 2                   -0.727498           -0.663447           -0.405879
# 3                    0.899903            1.605001            0.046338
# 4                   -0.018906            0.643243            1.525478

# %% [markdown]
# Keepig in mind that meaning a score of **0** is the national median, a **positive** score indicates a **higher deficit (worse)** than the median, and a **negative** score indicates a **lower deficit (better)** than the median; let's propose an interpretation, and naming, of our five distinct clusters:
#
#
# | Cluster | Label | Reason |
# |---------|-------|---------|
# | **0** | `Low Deficits - Well Performing` | All deficits negative (below average) |
# | **1** | `Sanitation Crisis Area` | Extreme sanitation deficit (+1.46) |
# | **2** | `Severe Multi-Dimensional Crisis` | All deficits highly positive (worst) |
# | **3** | `Education Challenge Area` | Only education deficit is positive |
# | **4** | `Education & Basic Needs Struggle` | High education & basic needs deficits |
#
# **Quick interpretation:**
# - **Cluster 0**: Best areas (intervention not urgent)
# - **Cluster 2**: Worst areas (need immediate comprehensive intervention)
# - **Clusters 1,3,4**: Need targeted interventions for specific deficits

# %% [markdown]
# ## Regionalization: Spatial Clustering
#
# Regionalization is the process of **clustering cases into contiguous regions** based on shared characteristics. In our work, the goal is to create socio-economic zones where districts within a zone are similar to each other and geographically connected.
#
# Conventional clustering (like KMeans above) group districts based only on their **deficit scores** (Education, NBI, Sanitation), but you see  a messy, fragmented map.  **Spatial Clustering (Regionalization) will wotk differently following:**
#
# 1.  **Attribute Similarity:** It still requires districts to have similar socio-economic **deficits** (based on your Robust Z-scores).
# 2.  **Contiguity Constraint:** It adds the rule that a district can **only be grouped with a neighbor it physically shares a border with**.
#
# By enforcing this contiguity, spatial clustering ensures that the final $K=5$ groups  are not scattered patches but are **contiguous, policy-relevant territorial blocks**.
#
# This way Spatial clustering tries building regions that are both **statistically coherent** (similar deficit profiles) and **geographically coherent** (connected in space). A good regionalization  makes the results useful for regional planning, resource allocation, and targeted policy intervention.

# %% [markdown]
# Let's compute the neigborhood matrix:

# %%
# for mos cases except spatial kmeans
peru_perim_graph = Graph.build_contiguity(DisMap, by_perimeter=True)
peru_perim_graph=peru_perim_graph.transform("r")

# for spatial kmeans
from libpysal.weights import W # Import W for the conversion
peru_perim = peru_perim_graph.to_W()
peru_perim.transform = "r"

# %% [markdown]
# ### 1. RegionKMeansHeuristic
#
#
# **Input:**
# - Geographic coordinates of each unit
# - The number of regions (K) needed
# - Attribute data for clustering
#
# **Process:**
# Iterative refinement combining spatial and attribute similarity:
# - Start with K random seed locations as initial region centers
# - In each iteration:
#   - Assign each unit to the closest region center considering both:
#     - Spatial proximity (geographic distance)
#     - Attribute similarity (feature space distance)
#   - Update region centers based on current assignments
# - Continue until assignments stabilize
#
# **Output:**
# - Geographic units partitioned into K regions
# - Regions balance spatial compactness with attribute homogeneity
#
#
# We can easily get these clusters using:

# %%
from spopt.region import RegionKMeansHeuristic as RKMeans

RKMeans_model = RKMeans(DisMap[clusterNames].values, K_target, w=peru_perim)
# computing
RKMeans_model.solve()

# %% [markdown]
# Now, a new column with the cluster labels.

# %%
DisMap['deficit_k5R'] = RKMeans_model.labels_

# %% [markdown]
# ### 2. AZP (A Priori Zoning Problem)
#
# AZP is one of the earliest and most direct algorithms for spatial clustering.
#
# **Input:**
# - A graph representing neighborhood relationships
# - The number of regions (K) needed
# - An initial random partition of regions
#
# **Process:**
# Iteratively improve region assignments through "node swapping" where:
# - Each geographic unit considers moving to adjacent regions
# - Moves are accepted if they improve regional homogeneity
# - The algorithm seeks to minimize within-region dissimilarity
# - Continues until no improving moves can be found
#
# **Output:**
# - Geographic units partitioned into K spatially contiguous regions
# - Regions are locally optimal in terms of internal homogeneity

# %%
from spopt.region import AZP

azp_model = AZP(
    gdf=DisMap,
    w=peru_perim_graph,
    attrs_name=clusterNames,
    n_clusters=K_target,
    random_state=RANDOM_SEED)
# computing
azp_model.solve()

# %% [markdown]
# New column with labels:

# %%
DisMap['deficit_azpR'] = azp_model.labels_

# %% [markdown]
# ### 3. Skater (Spatial 'K'luster Analysis by Tree Edge Removal)
#
#
# **Input:**
# - A graph representing neighborhood relationships
# - The number of regions (K) needed
#
# **Process:**
# Transform the neighborhood graph into a Minimum Spanning Tree ([MST](https://colab.research.google.com/drive/1CQwjJR6i_3X_8izLsDt-TPfbLtpCnN5T?usp=sharing)) where:
# - Each node connects to its most similar neighbors
# - Similarity is computed from social variables used for clustering
# - The MST minimizes total dissimilarity while maintaining full connectivity
#
# **Output:**
# - Geographic units partitioned into K spatially contiguous regions
# - Each region is internally homogeneous and geographically connected

# %%
from spopt.region import Skater

skater_model = Skater(
    gdf=DisMap,
    w=peru_perim_graph,
    attrs_name=clusterNames,
    n_clusters=K_target
)
# computing
skater_model.solve()

# %% [markdown]
# The cluster as a new column:

# %%
DisMap['deficit_skaterR'] = skater_model.labels_

# %% [markdown]
# ## Evaluating regionalization
#
# ### COMPACTNESS
#
# * **The isoperimetric quotient (IPQ)**. This compares the area of the region to the area of a circle with the same perimeter as the region.

# %%
from esda import shape as compactness

# columns with cluster labels
cluster_types_to_evaluate = ["deficit_k5","deficit_k5R","deficit_azpR","deficit_skaterR"]

results = {}

for cluster_type in cluster_types_to_evaluate:
    ## Dissolve the units into contiguous regions based on the cluster label
    regions = DisMap[[cluster_type, "geometry"]].dissolve(by=cluster_type)
    
    ## Compute the IPQ for the dissolved regions
    ipqs = compactness.isoperimetric_quotient(regions)
    
    ## Store the results
    results[cluster_type] = ipqs

# Create the final comparison DataFrame
ipq_comparison_df = pd.DataFrame(results)

# Adding the mean IPQ for each model
ipq_comparison_df.loc['Mean_IPQ'] = ipq_comparison_df.mean()

ipq_comparison_df
# Out:
#           deficit_k5  deficit_k5R  deficit_azpR  deficit_skaterR
# 0           0.011140     0.032495      0.006346         0.149062
# 1           0.003517     0.046610      0.008251         0.161451
# 2           0.003371     0.065282      0.032336         0.137044
# 3           0.009950     0.039288      0.008637         0.097102
# 4           0.003444     0.030583      0.039853         0.129602
# Mean_IPQ    0.006284     0.042852      0.019085         0.134852

# %% [markdown]
# * **Convex hull ratio (CHR)**. The CHR is simply the division of the area of the cluster by the area of its convex hull.

# %%
from esda import shape as compactness
results={}
for cluster_type in cluster_types_to_evaluate:
    ## Dissolve the units into contiguous regions based on the cluster label
    regions = DisMap[[cluster_type, "geometry"]].dissolve(by=cluster_type)
    ## Compute the CHR for the dissolved regions
    chullr = compactness.convex_hull_ratio(regions)
    ## Store the results
    results[cluster_type] = chullr

# Create the final comparison DataFrame
chr_comparison_df = pd.DataFrame(results)

# Adding the mean IPQ for each model
chr_comparison_df.loc['Mean_CHR'] = chr_comparison_df.mean()

# see
chr_comparison_df
# Out:
#           deficit_k5  deficit_k5R  deficit_azpR  deficit_skaterR
# 0           0.200208     0.587865      0.418136         0.798764
# 1           0.174867     0.507297      0.349051         0.767438
# 2           0.162907     0.729431      0.537696         0.721373
# 3           0.243420     0.569770      0.375942         0.607530
# 4           0.203092     0.554506      0.418602         0.641944
# Mean_CHR    0.196899     0.589774      0.419885         0.707410

# %% [markdown]
# Both **Isoperimetric Quotient (IPQ)** and **Convex Hull Ratio (CHR)** are metrics used to assess the **spatial compactness** of a polygon (like a geographic region), but they quantify compactness based on different geometric ideals.
#
# Here is a breakdown of their differences, how they are calculated, and what they measure:
#
#
# | Feature | Isoperimetric Quotient (IPQ) | Convex Hull Ratio (CHR) |
# | :--- | :--- | :--- |
# | **Ideal Shape** | **Circle** (the most compact shape) | **Any Convex Shape** (the simplest possible enclosure) |
# | **Formula** | $$\text{IPQ} = \frac{4\pi \cdot \text{Area}}{\text{Perimeter}^2}$$|$$\text{CHR} = \frac{\text{Area of the Region}}{\text{Area of the Convex Hull}}$$ |
# | **Range** | $0$ (least compact) to **$1.0$** (perfect circle) | $0$ (least compact) to **$1.0$** (perfectly convex) |
# | **Focus** | **Boundary Complexity/Elongation:** It penalizes long, wiggly, or highly elongated shapes by squaring the perimeter. | **Boundary Indentation/Concavity:** It penalizes "pitted" or "re-entrant" shapes where the boundary folds inward. |
# | **Use Case** | Excellent for assessing **efficiency** and **elongation** (e.g., in electoral districts). | Excellent for assessing **irregularity** and **concavity** (e.g., in regionalization studies). |

# %% [markdown]
# ### HOMOGENEITY
#
# Homogeneity, in the context of spatial clustering and regionalization (like with PySAL), refers to the **degree of similarity** among the smaller geographic units *within* a newly formed, larger region.
#
# Simply put, it measures **how alike the members of a group are.**
#
# Homogeneity is the **primary objective** of spatial clustering algorithms like RegionKMeans, AZP, and SKATER. These methods are designed to create regions where the difference in the chosen attributes (features) is minimized internally, even while adhering to the constraint of spatial contiguity.
#
# Homogeneity is assessed using the **attribute data** ($\mathbf{X}$) used for clustering (our _deficit variables_). Homogeneity is mathematically quantified using measures of **dispersion** or **variance** within each cluster. Let's compute the  **Calinski-Harabasz (CH) Score** ; and **Silhouette (SIL) Score**:

# %%
from sklearn import metrics

fit_scores = []

for cluster_type in cluster_types_to_evaluate:
    ch_score = metrics.calinski_harabasz_score(
        DisMap[clusterNames],# using scaled variables
        DisMap[cluster_type])# using these labels
    sil_score = metrics.silhouette_score(
        DisMap[clusterNames],DisMap[cluster_type]) #same as above
    
    # appending 
    fit_scores.append((cluster_type, ch_score,sil_score))


# re-arrange the scores into a dataframe for display
colNames=["cluster type", "CH score", "SIL score"]
pd.DataFrame(fit_scores, columns=colNames).set_index("cluster type")
# Out:
#                     CH score  SIL score
# cluster type
# deficit_k5       1204.818962   0.327515
# deficit_k5R       108.189487  -0.033656
# deficit_azpR      131.739950  -0.038092
# deficit_skaterR    85.945036  -0.114469

# %% [markdown]
# Here is a comparison table outlining the core differences between the two metrics:
#
# | Feature | Silhouette Score (SIL) | Calinski-Harabasz (CH) Score |
# | :--- | :--- | :--- |
# | **Calculation Base** | **Point-to-Point Distance** (Compares distance to own cluster vs. next-nearest cluster) | **Variance/Centroid Distance** (Ratio of between-cluster variance (SSB) to within-cluster variance (SSW)) |
# | **Range** | **$-1$ to $+1$** | $\ge 0$ (Unbounded) |
# | **Interpretation** | Closer to **+1** means high cohesion and high separation. | Higher values mean high cohesion and high separation. |
# | **Best Use** | Assessing **cluster tightness** and identifying poorly classified/ambiguous points. | Quickly identifying the **optimal number of clusters** ($k$). |
#
#
# Our table compares the homogeneity and separation of four different regionalization solutions for the `deficit` variable.
#
# | Metric | cluster type |
# | :--- | :--- |
# | **Benchmark (Non-Spatial)** |  `deficit_k5` |
# | **Spatial 1 (RegionKMeans)** |  `deficit_k5R` |
# | **Spatial 2 (AZP)** | `deficit_azpR` |
# | **Spatial 3 (SKATER)** | `deficit_skaterR` |
#
# The results show a stark contrast between the **non-spatial K-means benchmark** and the three **spatially constrained regionalization methods**:
#
# * **Massive Drop in CH Score in all Spatial techniques:** The spatial constraint (forcing regions to be contiguous) introduces a **significant cost** in terms of attribute homogeneity. The algorithms have to group adjacent units, even if they are very different in terms of `deficit` attributes, leading to much lower separation (SSB) and higher internal variance (SSW). This is normal and expected when moving from non-spatial to spatial clustering.
#
# * **Positive vs. Negative SIL Score:** The non-spatial K-means (`deficit_k5`) has a moderately good (positive) SIL score, while, **all three spatial solutions** have **negative** SIL scores. A negative Silhouette Score means that, on average, the units are **closer to the centroid of another region** (their neighbor) than they are to their own region's centroid. This reinforces the finding that the spatial constraint is forcing highly non-homogeneous groupings.
#
# Comparing the three spatial methods that adhere to the contiguity constraint:
#
# * **Best Homogeneity/Separation (Highest CH):** **AZP** (`deficit_azpR`) got the highest  CH score. This suggests that, among the constrained solutions, AZP found the regional configuration that best balanced internal similarity and external separation.
# * **Worst Homogeneity/Separation (Lowest SIL):** **SKATER** (`deficit_skaterR`) has the lowest SIL score. This indicates that SKATER produced the most ambiguous and least cohesive regions, relative to the two k-means-based methods (RegionKMeans and AZP).
# * **Regional-k-means (`deficit_k5R`):** This solution falls between AZP and SKATER in quality.
#
# Based purely on homogeneity and separation metrics, **AZP is the best performing regionalization method** for the `deficit` variable, although all spatial solutions show a substantial penalty for enforcing spatial contiguity.

# %% [markdown]
# In summary,
#
#
# **Choose AZP if... (The Statistical Path)** if the primary goal is to **model or explain** the 'deficit' attribute using the new regional structure.
#
# * **Policy Analysis:** You are trying to understand the spatial distribution and clustering of the deficit for academic research or modeling purposes.
# * **Predictive Modeling:** The region IDs will be used as a variable in a regression or machine learning model, and you need the strongest possible signal (least internal noise) from your regional groups.
# * **Targeting:** You need to identify areas where the average characteristics are most uniform to ensure any intervention is perfectly tailored to the demographic/economic reality of that region.
#
# **Choose SKATER if... (The Practical Path)** if the results will be used to create **real-world administrative or political boundaries** where shape and simplicity matter most.
#
# * **Administrative/Service Areas:** The regions will define boundaries for resource allocation, local governance, or service delivery (e.g., school districts, health zones). Irregular shapes lead to inefficient routes and unequal service distribution.
# * **Electoral Redistricting:** Compactness and simplicity are often legal or ethical requirements in defining political districts to prevent gerrymandering.
# * **Visualization:** You need a map that is clean, easy to interpret, and visually representative without highly complex, interdigitated boundaries.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming DisMap is your GeoDataFrame with the cluster columns
cluster_types = ["deficit_k5", "deficit_k5R", "deficit_azpR", "deficit_skaterR"]
titles = ["K-Means", "RegionKMeans", "AZP", "SKATER"]

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

# Find the maximum number of clusters across all methods for consistent coloring
max_clusters = max([DisMap[ct].nunique() for ct in cluster_types])

for i, (cluster_type, title) in enumerate(zip(cluster_types, titles)):
    # Plot with consistent colormap
    DisMap.plot(column=cluster_type, 
                ax=axes[i],
                categorical=True,
                legend=True,
                cmap='tab10',  # Consistent colors
                edgecolor=None,
                linewidth=0.3)
    
    axes[i].set_title(f'{title}', fontsize=14, fontweight='bold')
    axes[i].set_axis_off()

plt.suptitle('Comparison when K is 5\n (color can not be compared without profiling)', 
             fontsize=16, fontweight='bold',color='blue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conventional Regression
#
#
# Let's represent this model:
#
# $$\text{BasicNeeds\_deficit\_pct} = \beta_0 + \beta_1 (\text{Sanitation\_deficit\_pct}) + \beta_2 (\text{Education\_deficit\_pct}) + \epsilon$$
#
# The model attempts to predict the **Percentage of Population with Unmet Basic Needs (NBI)** using the **Percentage with Completed High-School Education** and the **Percentage of Households Lacking Sanitation**.

# %%
from pysal.model import spreg

dep_var_name='BasicNeeds_deficit_pct'
ind_vars_names=['Sanitation_deficit_pct', 'Education_deficit_pct']

ols_model = spreg.OLS(
    # Dependent variable
    DisMap[dep_var_name].values,
    # Independent variables
    DisMap[ind_vars_names].values,
    # Dependent variable name
    name_y=dep_var_name,
    # Independent variable name
    name_x=ind_vars_names,
    name_ds='DisMap')

print(ols_model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :      DisMap
# Weights matrix      :        None
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           3
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1868
# R-squared           :      0.5307
# Adjusted R-squared  :      0.5302
# Sum squared residual:      293744                F-statistic           :   1056.1675
# Sigma-square        :     157.251                Prob(F-statistic)     :  1.384e-307
# S.E. of regression  :      12.540                Log likelihood        :   -7384.944
# Sigma-square ML     :     156.999                Akaike info criterion :   14775.888
# S.E of regression ML:     12.5299                Schwarz criterion     :   14792.491
#
# ...

# %% [markdown]
# Here is a full interpretation:
#
# 1. **Model Fit and Significance**
#
# | Statistic | Value | Interpretation |
# | :--- | :--- | :--- |
# | **R-squared** | **0.5307** | The independent variables (Sanitation and Education deficits) explain about **53.1%** of the variation in the Basic Needs Deficit. This is a good fit. |
# | **F-statistic** | $1056.17$ | Highly significant (Prob $\approx 0.0000$). The model is **statistically valid** and the coefficients are not all zero. |
# | **S.E. of regression** | $12.540$ | The typical size of the residual (prediction error) is $\pm 12.54$ percentage points. |
#
# 2. **Coefficient Significance**
#
# All coefficients are highly statistically significant (Probability $\approx 0.0000$).
#
# * **CONSTANT (11.23):** If both Sanitation and Education deficits were 0%, the predicted Basic Needs Deficit would be around 11.23%.
# * **Sanitation\_deficit\_pct (0.671):** For every 1 percentage point increase in the **Sanitation Deficit**, the Basic Needs Deficit is predicted to increase by **0.67 percentage points**, holding Education constant. This is the **strongest predictor**.
# * **Education\_deficit\_pct (0.359):** For every 1 percentage point increase in the **Education Deficit**, the Basic Needs Deficit is predicted to increase by **0.36 percentage points**, holding Sanitation constant.
#
#
# 3. **OLS Diagnostics**
#
# The diagnostics reveal  violations of two critical assumptions of the OLS model:
#
# >Test on Normality of Errors: **Jarque-Bera Test** gives $1032.666$, with **Prob: $0.0000$**. This leads us to **reject the null hypothesis** that the errors are normally distributed. The model residuals are non-normal (they are likely skewed or have heavy tails).
#
# > Diagnostics for Heteroskedasticity (Non-constant Variance): * **Breusch-Pagan Test / Koenker-Bassett Test** both have **Prob: $0.0000$**. The p-values are extremely low, which leads us to **reject the null hypothesis** of homoskedasticity (constant variance). This means the **variance of the model errors changes across your study area**. The model errors are larger in some districts than others, then the coefficients we see as highly significant may not be reliable.
#
# > Multicollinearity Condition Number is **Value:** **6.706**. This is very low (well below the common threshold of 30). This indicates **low multicollinearity**. Our two independent variables are not overly correlated with each other, which is good.
#
#
# The OLS diagnostics alone are enough to say that the OLS model is **invalid for reliable inference**. However, the OLS diagnostics **do not inform is my neighbors are playing a role**.

# %% [markdown]
# ### Spatial Regression need?
#
# Let's re run the previous code, but requesting **spatial disgnostics**, for that we input the adjacency matrix (peru_perim_graph)

# %%
ols_model_withW = spreg.OLS(
    # Dependent variable
    DisMap[dep_var_name].values,
    # Independent variables
    DisMap[ind_vars_names].values,
    # Dependent variable name
    name_y=dep_var_name,
    # Independent variable name
    name_x=ind_vars_names,
    name_ds='DisMap',
    w=peru_perim_graph,
    spat_diag=True)

print(ols_model_withW.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :      DisMap
# Weights matrix      :     unknown
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           3
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1868
# R-squared           :      0.5307
# Adjusted R-squared  :      0.5302
# Sum squared residual:      293744                F-statistic           :   1056.1675
# Sigma-square        :     157.251                Prob(F-statistic)     :  1.384e-307
# S.E. of regression  :      12.540                Log likelihood        :   -7384.944
# Sigma-square ML     :     156.999                Akaike info criterion :   14775.888
# S.E of regression ML:     12.5299                Schwarz criterion     :   14792.491
#
# ...

# %% [markdown]
# We strongly confirm that our OLS model is suffering from severe **spatial autocorrelation** and should not be used for reliable inference. Here we have some options to consider:
#
#
# | Spatial Correlation Location | Model Term | Interpretation & Why it's Needed | Spatial Model to Use |
# | :--- | :--- | :--- | :--- |
# | **Control the spatial correlation in the dependent variable** ($Y$) | $\rho W Y$ (Spatial Lag) | **Interaction/Spillover:** Your outcome is directly affected by the average outcome in neighboring areas. | **Spatial Autoregressive Model (SAR)** |
# | **Control the spatial correlation in the independent variables** ($X$) | $\gamma W X$ (Spatial Durbin) | **Exogenous Spillover:** Your outcome is directly affected by the average independent variable values in neighboring areas. | **Spatial Durbin Model (SDM)** |
# | **Control the spatial correlation in regression residuals** ($\epsilon$) | $\lambda W \epsilon$ (Spatial Error) | **Unmodeled Factors:** The spatial clustering is due to unobserved, spatially correlated factors (e.g., policy or environment) not included in $X$. | **Spatial Error Model (SEM)** |
#
# The diagnostics arguably did not favor the SAR option, while the other require a closer look. Nevertheless, let's explore all the options.

# %% [markdown]
# ## Spatial Regression: SAR
#
# The Spatial Autoregressive Model (SAR / Spatial Lag) corrects for **spatial spillover in the dependent variable** (the $\rho WY$ term).
#
# * **When to Use It (Diagnostics):** When the **Robust LM (lag)** is highly significant. (Our Robust LM (lag) was not significant, making this model less likely to be the best fit).
#
# * **Model Structure:**
#     $$Y = \rho W Y + X\beta + \epsilon$$
#     * $\rho$: The spatial autocorrelation coefficient (measures the strength of the lag effect).
#     * $WY$: The spatially lagged dependent variable (neighbors' average deficit).
#
# * **Interpretation:** The significant $\rho$ means that a district's Basic Needs Deficit is **directly and positively influenced by the Basic Needs Deficit of its neighboring districts** (e.g., policy or social influence spreading across boundaries).
#
#
# * **Key Challenge:** Unlike OLS, the $\beta$ coefficients **cannot be interpreted directly** as marginal effects; you must calculate **Direct, Indirect (Spillover), and Total effects**.

# %% [markdown]
# In SAR, the Moran's I may be significant for the dependent variable....is it?

# %%
import esda 

MoranGlobal_Dep = esda.Moran(DisMap[dep_var_name], peru_perim) #notice W
MoranGlobal_Dep.I,MoranGlobal_Dep.p_sim
# Out:
# (np.float64(0.5483273619732717), np.float64(0.001))

# %%
SAR_model = spreg.GM_Lag(
    # Dependent variable
    DisMap[dep_var_name],
    # Independent variables
    DisMap[ind_vars_names],
    w=peru_perim_graph,
    # Dependent variable name
    name_y=dep_var_name,
    # Independent variable name
    name_x=ind_vars_names,
    name_w='peru_perim_graph',
    name_ds='DisMap',
    robust='white'
    )

print(SAR_model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :      DisMap
# Weights matrix      :peru_perim_graph
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           4
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1867
# Pseudo R-squared    :      0.5678
# Spatial Pseudo R-squared:  0.5308
#
# White Standard Errors
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT         9.76711         1.04812         9.31866         0.00000
# ...

# %% [markdown]
# Our SAR model  attempts to capture spatial spillover ($\rho W Y$) while correcting the standard errors for the heteroskedasticity found in your initial OLS.:
#
# $$\text{BasicNeeds\_deficit\_pct} = \beta_0 + \beta_1 (\text{Sanitation\_deficit\_pct}) + \beta_2 (\text{Education\_deficit\_pct}) + \rho \cdot W (\text{BasicNeeds\_deficit\_pct}) + \epsilon$$
#
# * **Spatial Lag Coefficient ($\rho$)**:
#
# | Variable | Coefficient | Std.Error | z-Statistic | **Probability** |
# | :--- | :--- | :--- | :--- | :--- |
# | **W\_BasicNeeds\_deficit\_pct** ($\rho$) | **0.06903** | $0.03541$ | $1.94919$ | **0.05127** |
#
# * **Interpretation:** The $\rho$ coefficient is virtually unchanged from the non-robust SAR run, but the standard error has been slightly adjusted (improved precision). The spatial lag remains **marginally significant** at the $5.1\%$ level (just above the conventional $5\%$ cutoff). This suggests a weak positive spillover: a 1-unit increase in the average deficit of neighbors is associated with a 0.069-unit increase in the district's own deficit.
#
# * **Goodness-of-Fit**:
#
# | Statistic | OLS ($R^2$) | SAR (Pseudo $R^2$) |
# | :--- | :--- | :--- |
# | **Value** | $0.5307$ | **$0.5678$** |
#
# The SAR model explains a slightly higher proportion of the variance in the dependent variable than the OLS model (56.8% vs. 53.1%). This indicates a modest improvement in model fit by accounting for the spatial lag.
#
# * **Diagnostics for Spatial Dependence**:
#
# | Test | DF | Value | PROB | Interpretation |
# | :--- | :--- | :--- | :--- | :--- |
# | **Anselin-Kelejian Test** | 1 | $132.568$ | **0.0000** | This is a test for remaining spatial autocorrelation in the **residuals** after fitting the SAR model. The highly significant p-value means **you still have spatial error dependence** ($\lambda W\epsilon$) in your model. |
#
#
# > **The SAR model has NOT fully corrected the spatial dependence problem, as the model residuals are still spatially correlated.**
#
#
# In a SAR model, the coefficients ($\beta$) are not direct marginal effects because a change in $X$ in one location affects the dependent variable in all other locations (due to the feedback loop of $\rho WY$). Therefore, the impacts are broken down:
#
# | Variable | Robust Direct | Robust Indirect | Robust Total |
# | :--- | :--- | :--- | :--- |
# | Sanitation\_deficit\_pct | $\mathbf{0.6530}$ | $0.0484$ | $0.7014$ |
# | Education\_deficit\_pct | $0.3386$ | $0.0251$ | $0.3637$ |
#
# * The **Direct Impacts** of both Sanitation and Education deficits remain highly significant ($\text{Prob} = 0.00000$), confirming their strong local effect.
# * The **Indirect Impacts** (spillovers) are small but are now based on reliable standard errors.
#
#
# The **Robust SAR Model is still statistically insufficient** because it fails to capture all spatial dependence. The remaining spatial structure in the errors ($\lambda W \epsilon$) means the model is misspecified, and the coefficients, while robustly estimated, are still subject to potential **omitted variable bias** (missing the $\mathbf{WX}$ and/or $\lambda W \epsilon$ components).
#
# This robust test provides a definitive rejection of the SAR model.

# %% [markdown]
# ## Spatial Regression: SEM
#
#
# The **Spatial Error Model (SEM)** corrects for **unmodeled spatial clustering in the errors** (the $\lambda W\epsilon$ term).
#
# * **When to Use It (Diagnostics):** When the **Robust LM (error)** is highly significant, and the Robust LM (lag) is *not* (as in our case).
#
# * **Model Structure:**
#     $$Y = X\beta + \lambda W\mu + \epsilon$$
#     * $\lambda$: The spatial autocorrelation coefficient in the error term.
#     * $W\mu$: The spatially lagged error term.
#
# * **Interpretation:** The significant $\lambda$ indicates that there is **spatial dependence in unobserved factors**. For example, similar administrative practices or unmeasured environmental factors shared by neighboring districts are causing the model to systematically under- or over-predict the deficit in a clustered pattern.
#
# * **Effect on Coefficients ($\beta$):** The SEM primary goal is to **correct standard errors** and make the coefficients ($\beta$) reliable, but it assumes the estimated $\beta$ coefficients for $X$ are the true effects.

# %%
MoranGlobal_error = esda.Moran(ols_model.u, peru_perim)
MoranGlobal_error.I,MoranGlobal_error.p_sim
# Out:
# (np.float64(0.5842351885781318), np.float64(0.001))

# %%
SEM_model = spreg.GM_Error_Het(
    # Dependent variable
    DisMap[dep_var_name].values,
    # Independent variables
    DisMap[ind_vars_names].values,
    w=peru_perim_graph,
    # Dependent variable name
    name_y=dep_var_name,
    # Independent variable name
    name_x=ind_vars_names,
    name_w='DisMap',
    name_ds='peru_perim_graph'
    )

print(SEM_model.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: GM SPATIALLY WEIGHTED LEAST SQUARES (HET)
# ------------------------------------------------------------
# Data set            :peru_perim_graph
# Weights matrix      :      DisMap
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           3
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1868
# Pseudo R-squared    :      0.5120
# N. of iterations    :           1                Step1c computed       :          No
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        16.29115         1.15100        14.15394         0.00000
# ...

# %% [markdown]
# This model addresses both the **spatial autocorrelation** ($\lambda$) and the **heteroskedasticity** (non-constant variance) found in your initial OLS diagnostics.
#
# $$\text{BasicNeeds\_deficit\_pct} =  \beta_0 + \beta_1 (\text{Sanitation\_deficit\_pct}) + \beta_2 (\text{Education\_deficit\_pct}) + \boldsymbol{\mu}$$
#
# Where the error term $\boldsymbol{\mu}$ has a spatial structure defined by:
#
# $$\boldsymbol{\mu} = \lambda \mathbf{W}\boldsymbol{\mu} + \boldsymbol{\epsilon}$$
#
#
# This equation proposes that the **Basic Needs Deficit** is determined by your explanatory variables ($\beta_1, \beta_2$) **plus** a large, spatially clustered error ($\boldsymbol{\mu}$) that is shared among neighboring districts.
#
#
# This model uses a Generalized Moments (GM) estimator that is robust to heteroskedasticity. The significance of the spatial parameter ($\lambda$) is estimated robustly.
#
# * **Spatial Error Coefficient ($\lambda$)**
#
# | Variable | Coefficient | Std.Error | z-Statistic | **Probability** |
# | :--- | :--- | :--- | :--- | :--- |
# | **lambda ($\lambda$)** | **0.78067** | **0.01853** | **42.13485** | **0.00000** |
#
# * **Interpretation:** The $\lambda$ value of $\mathbf{0.781}$ is highly significant ($\text{Prob} = 0.00000$). This confirms that **$78.1\%$** of the residual variance is explained by a spatially autocorrelated error process. The spatial structure is extremely strong and confirms the necessity of this model.
#
# * **Heteroskedasticity-Robust Coefficients**
#
# The standard errors and z-statistics here are corrected for both spatial error and heteroskedasticity, making them the **most reliable estimates so far**.
#
# | Variable | ML-SEM Coeff. | **Robust SEM Coeff.** | Robust SEM Std.Error | Interpretation |
# | :--- | :--- | :--- | :--- | :--- |
# | **CONSTANT** | $16.473$ | $\mathbf{16.291}$ | $1.15100$ | Robust baseline deficit. |
# | **Sanitation\_deficit\_pct**| $0.751$ | $\mathbf{0.745}$ | $\mathbf{0.01498}$ | The **Sanitation Deficit** impact is confirmed as dominant and highly precise. |
# | **Education\_deficit\_pct**| $0.191$ | $\mathbf{0.204}$ | $\mathbf{0.02145}$ | The **Education Deficit** impact is confirmed as significantly weaker than OLS suggested. |

# %% [markdown]
# ### Spatial Regression: SLX-Error
#
#
# The Spatially Lagged X with Spatial Error Model (**SLX-Error Model**) is a hybrid spatial regression model designed to account for two distinct sources of spatial dependence simultaneously:
#
# 1.  **Exogenous Spatial Interaction (The SLX Component):** The influence of independent variables ($\mathbf{X}$) in neighboring areas directly affecting the dependent variable ($\mathbf{Y}$) in the local area.
# 2.  **Unmodeled Spatial Dependence (The Error Component):** The spatial clustering of unobserved factors that are not captured by the independent variables, which shows up in the error term.
#
# The SLX-Error model essentially takes the standard **Spatial Error Model (SEM)** and adds the **Spatially Lagged X ($\mathbf{W X}$) terms**.
#
# The SLX-Error model is defined by the following two equations:
#
# $$
# \begin{aligned}
# \mathbf{Y} &= \mathbf{X}\boldsymbol{\beta} + \mathbf{W X}\boldsymbol{\gamma} + \boldsymbol{\mu} \\
# \boldsymbol{\mu} &= \lambda \mathbf{W}\boldsymbol{\epsilon} + \boldsymbol{\epsilon}
# \end{aligned}
# $$
#
#
# | Term | Description | Role in the Model |
# | :--- | :--- | :--- |
# | $\mathbf{W X}\boldsymbol{\gamma}$ | **Spatially Lagged Independent Variables (SLX)** | Captures **exogenous spillovers**. For example, your basic needs deficit is affected by your neighbor's sanitation deficit. |
# | $\lambda \mathbf{W}\boldsymbol{\epsilon}$ | **Spatially Autocorrelated Error Term** | Captures **unobserved factors** that are spatially clustered (e.g., shared unmeasured infrastructure or regional policy effects). |
#
# Key Advantages and Interpretation:
#
# * **Exogenous Spillover:** The $\mathbf{W X}\boldsymbol{\gamma}$ terms allow for the direct quantification and interpretation of **exogenous spillovers**. The coefficient $\boldsymbol{\gamma}$ is interpreted directly: a change in a neighbor's $X$ leads to a $\gamma$-unit change in your $Y$.
# * **Correction for Bias:** The $\lambda$ term ensures that the $\boldsymbol{\beta}$ and $\boldsymbol{\gamma}$ coefficients are **unbiased and efficient** by clearing the residuals of spatial autocorrelation.
# * **Stability:** Crucially, the SLX-Error model **does not include the endogenous feedback loop ($\rho \mathbf{W Y}$)**. This makes it a structurally stable model, avoiding the instability issues (like $\rho > 1$) that you encountered with the General Moments SDM.
#
# The SLX-Error model is often used when diagnostics strongly point to both **error dependence** and **exogenous spillovers**, and when the endogenous feedback ($\rho \mathbf{W Y}$) is found to be either insignificant or unstable.

# %%
from pysal.model.spreg import GM_Error_Het

SLXE_model_final = GM_Error_Het(
    DisMap[dep_var_name].values,
    DisMap[ind_vars_names].values,
    w=peru_perim_graph,
    slx_lags=1,              # Adds the W*X terms
    name_y=dep_var_name,
    name_x=ind_vars_names,
    name_w='peru_perim_graph',
    name_ds='DisMap'
)

print(SLXE_model_final.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: GM SPATIALLY WEIGHTED LEAST SQUARES (HET) WITH SLX (SLX-Error)
# ---------------------------------------------------------------------------------
# Data set            :      DisMap
# Weights matrix      :peru_perim_graph
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           5
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1866
# Pseudo R-squared    :      0.5358
# N. of iterations    :           1                Step1c computed       :          No
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# This equation shows how the dependent variable ($\mathbf{Y}$) is determined by local factors ($\mathbf{X}$), neighbors' factors ($\mathbf{W X}$), and the spatially autocorrelated error ($\boldsymbol{\mu}$):
#
# $$
# \begin{aligned}
# \text{BasicNeeds\_deficit\_pct} = & \ \beta_0 + \beta_1 (\text{Sanitation\_deficit\_pct}) + \beta_2 (\text{Education\_deficit\_pct}) \\
# & + \gamma_1 \mathbf{W}(\text{Sanitation\_deficit\_pct}) + \gamma_2 \mathbf{W}(\text{Education\_deficit\_pct}) + \boldsymbol{\mu}
# \end{aligned}
# $$
#
#
# This equation defines how the error term ($\boldsymbol{\mu}$) is spatially autocorrelated:
#
# $$\boldsymbol{\mu} = \lambda \mathbf{W}\boldsymbol{\epsilon} + \boldsymbol{\epsilon}$$
#
# All standard errors are corrected for heteroskedasticity.
#
# * **Spatial Dependence and Correction**. The model successfully captures and corrects for the spatial issues identified in earlier diagnostics.
#
# | Variable | Coefficient | Std.Error | z-Statistic | **Probability** | Interpretation |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# | **lambda ($\lambda$)** | **$0.77044$** | $0.01931$ | $39.89069$ | **$0.00000$** | **Strong Spatial Error:** $\lambda$ is highly significant, confirming that $\approx 77\%$ of the unexplained variance in the Basic Needs Deficit is due to **unobserved, spatially clustered factors** (e.g., shared regional policies, environmental shocks) that are not included in the $\mathbf{X}$ variables. |
#
# ---
#
# * **Core Direct Effects ($\mathbf{X}\boldsymbol{\beta}$)**.  These coefficients measure the impact of a district's own deficits on its Basic Needs Deficit, after controlling for all spatial effects.
#
# | Variable | Coefficient ($\boldsymbol{\beta}$) | Probability | Interpretation |
# | :--- | :--- | :--- | :--- |
# | **Sanitation\_deficit\_pct** | **$0.73448$** | $0.00000$ | **Dominant Factor:** A 1-unit increase in a district's own Sanitation Deficit increases its Basic Needs Deficit by $\mathbf{0.73}$ units. This is the largest and most significant local driver. |
# | **Education\_deficit\_pct** | **$0.21065$** | $0.00000$ | **Significant Factor:** A 1-unit increase in a district's own Education Deficit increases its Basic Needs Deficit by $\mathbf{0.21}$ units. |
#
# * **Exogenous Spillover Effects ($\mathbf{W X}\boldsymbol{\gamma}$)**. These coefficients reveal how a neighbor's deficit (the average of its neighbors' $\mathbf{X}$ variables) affects the local district's Basic Needs Deficit. These effects are direct and do not involve a feedback loop.
#
# | Variable | Coefficient ($\boldsymbol{\gamma}$) | Probability | Interpretation |
# | :--- | :--- | :--- | :--- |
# | **W\_Sanitation\_deficit\_pct** | **$-0.08473$** | **$0.01352$** | **Negative Spillover (Rivalry):** A higher average Sanitation Deficit in neighboring districts is associated with a **lower** Basic Needs Deficit in the local district. This suggests a competitive dynamic, where resources or attention are drawn away from the better-off local district to address the neighbor's critical sanitation issues. |
# | **W\_Education\_deficit\_pct** | **$0.10074$** | **$0.00826$** | **Positive Spillover (Contagion):** A higher average Education Deficit in neighboring districts is associated with a **higher** Basic Needs Deficit in the local district. This suggests a shared, contagious problem, possibly due to a shared regional school system failure or social policies that easily diffuse. |
#
#
# The Robust SLX-Error model demonstrates that the spatial dynamics of the Basic Needs Deficit are characterized by two distinct forces:
#
# 1.  **Strong Structural Clustring ($\lambda$):** The primary spatial dependence is structural, driven by hidden, unmeasured factors common to neighbors.
# 2.  **Contrasting Exogenous Spillovers ($\mathbf{W X}$):** The spillovers from neighbors' deficits operate in opposite directions:
#     * **Sanitation:** Exhibits **rivalry** (negative spillover).
#     * **Education:** Exhibits **contagion** (positive spillover).

# %% [markdown]
# ### Spatial Regression: SDM
#
# The Spatial Durbin Model (SDM) is a model that combines the SAR structure with the **spatial lag of the independent variables** (the $\gamma WX$ term).
#
# * **When to Use It (Diagnostics):** When both the **Robust LM (error)** and the **Robust LM WX test** are significant (as they are in our case).
# * **Model Structure:**
#     $$Y = \rho W Y + X\beta + W X \gamma + \epsilon$$
#     * $\rho W Y$: Neighbors' deficit influences your deficit.
#     * $W X \gamma$: Neighbors' **independent variables** (Sanitation and Education deficits) influence your deficit.
# * **Interpretation:** This model provides the **most complete picture of spillovers.** For example, not only does your neighbor's high Basic Needs Deficit affect yours ($\rho$), but your neighbor's high Education Deficit might also directly contribute to yours ($\gamma$).
# * **SDM's Advantage:** If the true data generating process is an SDM, omitting the $WX$ term leads to an omitted variable bias in the SAR model. The SDM avoids this risk, making it the **safest starting point**.
#
# ---

# %%
model_durbin = spreg.ML_Lag(DisMap[dep_var_name].values,
    DisMap[ind_vars_names].values,
    w=peru_perim_graph,
    name_y=dep_var_name,
    name_x=ind_vars_names,
    name_w='peru_perim_graph',
    name_ds='DisMap',
    slx_lags=1
                            
)
print(model_durbin.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL LAG WITH SLX - SPATIAL DURBIN MODEL (METHOD = FULL)
# -------------------------------------------------------------------------------------------------
# Data set            :      DisMap
# Weights matrix      :peru_perim_graph
# Dependent Variable  :BasicNeeds_deficit_pct                Number of Observations:        1871
# Mean dependent var  :     38.5867                Number of Variables   :           6
# S.D. dependent var  :     18.2951                Degrees of Freedom    :        1865
# Pseudo R-squared    :      0.7975
# Spatial Pseudo R-squared:  0.5478
# Log likelihood      :  -6766.4739
# Sigma-square ML     :     68.6540                Akaike info criterion :   13544.948
# S.E of regression   :      8.2858                Schwarz criterion     :   13578.153
#
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# The **Maximum Likelihood Spatial Durbin Model (SDM)** is defined by the following equation, which shows how a district's $\text{BasicNeeds\_deficit\_pct}$ is influenced by its own characteristics ($\mathbf{X}\boldsymbol{\beta}$), the endogenous feedback from its neighbors ($\rho \mathbf{W}\mathbf{Y}$), and the exogenous spillovers from its neighbors' characteristics ($\mathbf{W X}\boldsymbol{\gamma}$):
#
# $$
# \begin{aligned}
# \mathbf{Y} = \rho \mathbf{W}\mathbf{Y} + \mathbf{X}\boldsymbol{\beta} + \mathbf{W X}\boldsymbol{\gamma} + \boldsymbol{\epsilon}
# \end{aligned}
# $$
#
# **Expanded Equation with Your Variables:**
#
# $$
# \begin{aligned}
# \text{BasicNeeds\_deficit\_pct} = & \ 2.31782 \\
# & + 0.75938 \mathbf{W}(\text{BasicNeeds\_deficit\_pct}) \\
# & + 0.75246 (\text{Sanitation\_deficit\_pct}) - 0.61006 \mathbf{W}(\text{Sanitation\_deficit\_pct}) \\
# & + 0.18241 (\text{Education\_deficit\_pct}) - 0.08398 \mathbf{W}(\text{Education\_deficit\_pct}) \\
# & + \boldsymbol{\epsilon}
# \end{aligned}
# $$

# %% [markdown]
# * **Model Fit and Justification**:
#
# | Metric | Value | Interpretation |
# | :--- | :--- | :--- |
# | **Pseudo R-squared** | **$0.7975$** | The model explains nearly **$80\%$** of the variance in the Basic Needs Deficit, demonstrating an excellent fit. |
# | **AIC** | **$13544.948$** | This is the **lowest AIC** obtained across all stable models, statistically confirming the SDM is the preferred choice over the simpler SEM and SAR models. |
# | **Common Factor Test** | $\text{Prob} = \mathbf{0.0009}$ | **Highly Significant.** We formally **reject the hypothesis** that the SDM can be simplified to the SEM or SAR. The full structure is necessary. |
#
# * **Spatial Dependence Coefficients**.  All three main spatial terms are highly significant, confirming that spatial effects are fundamental to the process.
#
# | Variable | Coefficient | Probability | Interpretation |
# | :--- | :--- | :--- | :--- |
# | **W\_BasicNeeds\_deficit\_pct ($\rho$)** | **$0.75938$** | $0.00000$ | **Strong Endogenous Spillover:** The Basic Needs Deficit in a district is strongly and positively influenced by the deficit in its neighboring districts. This signifies a potent **feedback loop** where a high local deficit reinforces high deficits in the region. |
# | **W\_Sanitation\_deficit\_pct ($\gamma_1$)** | **$-0.61006$** | $0.00000$ | **Strong Negative Spillover (Rivalry):** A higher Sanitation Deficit in neighbors is associated with a **lower** Basic Needs Deficit locally. This suggests **competitive resource allocation** or displacement of issues. |
# | **W\_Education\_deficit\_pct ($\gamma_2$)** | **$-0.08398$** | $0.00044$ | **Significant Negative Spillover (Rivalry):** A higher Education Deficit in neighbors is also associated with a **lower** Basic Needs Deficit locally, reinforcing the competitive dynamic found in sanitation. |
#
# * **Core Direct Effects**. These coefficients ($\boldsymbol{\beta}$) show the local impact of the explanatory variables.
#
# | Variable | Coefficient ($\boldsymbol{\beta}$) | Probability | Interpretation |
# | :--- | :--- | :--- | :--- |
# | **Sanitation\_deficit\_pct** | **$0.75246$** | $0.00000$ | **Dominant Local Factor:** A 1-unit increase in a district's own Sanitation Deficit increases its Basic Needs Deficit by $\mathbf{0.75}$ units. |
# | **Education\_deficit\_pct** | **$0.18241$** | $0.00000$ | **Significant Local Factor:** A 1-unit increase in a district's own Education Deficit increases its Basic Needs Deficit by $\mathbf{0.18}$ units. |
#
# * **Spatial Durbin Model Impacts (Economic Interpretation)**.  The total effect of a change in an independent variable must be broken down into local (Direct) and neighborhood (Indirect) components.
#
# | Variable | Direct Impact | Indirect Impact (Spillover) | **Total Impact** | Interpretation |
# | :--- | :--- | :--- | :--- | :--- |
# | **Sanitation\_deficit\_pct** | **$0.7525$** | **$-0.1606$** | **$0.5918$** | **Local Dominance, Mitigated Spillover:** The strong local impact ($+0.75$) dominates, but the overall effect is reduced by the **negative spillover** (rivalry) from neighbors ($-\mathbf{0.16}$). |
# | **Education\_deficit\_pct** | **$0.1824$** | **$+0.2267$** | **$0.4091$** | **Neighbor-Driven Spillover:** The indirect effect ($+\mathbf{0.23}$) is larger than the direct effect ($+0.18$). This means the **spillover effect of the Education Deficit is stronger than its local effect**, resulting in a significant overall increase. |
